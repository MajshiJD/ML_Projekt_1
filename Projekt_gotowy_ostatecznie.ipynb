# %% [markdown]
# # Wstęp do uczenia maszynowego. Projekt nr 1.
#
# *Maciej Borkowski, Michał Chęć
# 21.04.2023r.*
#
# Zadaniem projektowym jest zrealizowanie zadania klasyfikacji binarnej na zbiorze danych numerycznych ze strony
# [https://www.kaggle.com/datasets/nextbigwhat/dataset-1](https://www.kaggle.com/datasets/nextbigwhat/dataset-1)

# %%
# ładujemy potrzebne pakiety
import pandas as pd
import numpy as np
from tabulate import tabulate
import matplotlib.pyplot as plt

from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.feature_selection import SelectKBest, SelectFromModel, SequentialFeatureSelector, RFE, VarianceThreshold
from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier

import warnings
import os
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore"

np.random.seed(42)

# %% [markdown]
# # 1. Import i podział danych

# %%
# wczytujemy całą ramkę danych
dataset = pd.read_csv("./data/dataset_1.csv")
df = dataset.copy()

# %%
# dzielimy dane, tworzymy zbiór do ewaluacji i do testów
train_set, eval_set = train_test_split(df, test_size=0.3, random_state=42)
train_df, test_df = train_test_split(train_set, test_size=0.3, random_state=42)
df = train_df.copy()

# %%
# sprawdzamy czy zmienna objaśniana ma mniej więcej ten sam współczynnik 1 w obu zbiorach
[dataset[dataset.target == 1].size/dataset.size,
 eval_set[eval_set.target == 1].size/eval_set.size,
 train_set[train_set.target == 1].size/train_set.size]
# Out:
# [0.03982, 0.04006666666666667, 0.039714285714285716]

# %% [markdown]
# # 2. EDA i preprocessing
#
# W tej części zapoznajemy się ze zbiorem danych, dokonujemy eksploracyjnej analizy danych i ich preprocessingu. Należy zaznaczyć, że opisany w tej częsci preprocessing jest dokonany jedynie na pewnych wybranych przez nas parametrach, które będziemy następnie dopiero stroić w zależności od modelu. Rezultatem preprocessingu z tej części jest klasa, której będziemy używać w pipe'ach i column transformerach.

# %%
df.shape
# Out:
# (24500, 301)

# %%
# sprawdzamy typy zmiennych i występowanie braków
df.iloc[:, 0:100].info()
df.iloc[:, 100:200].info()
df.iloc[:, 200:300].info()
df.target.info()
df.target.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24500 entries, 10182 to 15687
# Data columns (total 100 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   var_1    24500 non-null  int64
#  1   var_2    24500 non-null  int64
#  2   var_3    24500 non-null  float64
#  3   var_4    24500 non-null  float64
#  4   var_5    24500 non-null  float64
#  5   var_6    24500 non-null  int64
#  6   var_7    24500 non-null  int64
#  7   var_8    24500 non-null  int64
#  8   var_9    24500 non-null  int64
#  9   var_10   24500 non-null  int64
#  10  var_11   24500 non-null  float64
#  11  var_12   24500 non-null  float64
#  12  var_13   24500 non-null  float64
#  13  var_14   24500 non-null  int64
#  14  var_15   24500 non-null  int64
#  15  var_16   24500 non-null  float64
#  16  var_17   24500 non-null  float64
#  17  var_18   24500 non-null  float64
#  18  var_19   24500 non-null  int64
#  19  var_20   24500 non-null  int64
#  20  var_21   24500 non-null  float64
#  21  var_22   24500 non-null  float64
#  22  var_23   24500 non-null  int64
#  23  var_24   24500 non-null  int64
#  24  var_25   24500 non-null  int64
#  25  var_26   24500 non-null  float64
#  26  var_27   24500 non-null  float64
#  27  var_28   24500 non-null  int64
#  28  var_29   24500 non-null  float64
#  29  var_30   24500 non-null  float64
#  30  var_31   24500 non-null  int64
#  31  var_32   24500 non-null  float64
#  32  var_33   24500 non-null  int64
#  33  var_34   24500 non-null  int64
#  34  var_35   24500 non-null  float64
#  35  var_36   24500 non-null  int64
#  36  var_37   24500 non-null  int64
#  37  var_38   24500 non-null  int64
#  38  var_39   24500 non-null  float64
#  39  var_40   24500 non-null  float64
#  40  var_41   24500 non-null  float64
#  41  var_42   24500 non-null  float64
#  42  var_43   24500 non-null  int64
#  43  var_44   24500 non-null  int64
#  44  var_45   24500 non-null  int64
#  45  var_46   24500 non-null  float64
#  46  var_47   24500 non-null  float64
#  47  var_48   24500 non-null  float64
#  48  var_49   24500 non-null  int64
#  49  var_50   24500 non-null  float64
#  50  var_51   24500 non-null  int64
#  51  var_52   24500 non-null  int64
#  52  var_53   24500 non-null  int64
#  53  var_54   24500 non-null  int64
#  54  var_55   24500 non-null  float64
#  55  var_56   24500 non-null  int64
#  56  var_57   24500 non-null  float64
#  57  var_58   24500 non-null  int64
#  58  var_59   24500 non-null  int64
#  59  var_60   24500 non-null  int64
#  60  var_61   24500 non-null  int64
#  61  var_62   24500 non-null  int64
#  62  var_63   24500 non-null  int64
#  63  var_64   24500 non-null  float64
#  64  var_65   24500 non-null  float64
#  65  var_66   24500 non-null  int64
#  66  var_67   24500 non-null  int64
#  67  var_68   24500 non-null  int64
#  68  var_69   24500 non-null  int64
#  69  var_70   24500 non-null  int64
#  70  var_71   24500 non-null  int64
#  71  var_72   24500 non-null  int64
#  72  var_73   24500 non-null  int64
#  73  var_74   24500 non-null  int64
#  74  var_75   24500 non-null  float64
#  75  var_76   24500 non-null  float64
#  76  var_77   24500 non-null  float64
#  77  var_78   24500 non-null  float64
#  78  var_79   24500 non-null  float64
#  79  var_80   24500 non-null  int64
#  80  var_81   24500 non-null  int64
#  81  var_82   24500 non-null  int64
#  82  var_83   24500 non-null  int64
#  83  var_84   24500 non-null  int64
#  84  var_85   24500 non-null  float64
#  85  var_86   24500 non-null  float64
#  86  var_87   24500 non-null  int64
#  87  var_88   24500 non-null  int64
#  88  var_89   24500 non-null  float64
#  89  var_90   24500 non-null  float64
#  90  var_91   24500 non-null  float64
#  91  var_92   24500 non-null  int64
#  92  var_93   24500 non-null  float64
#  93  var_94   24500 non-null  int64
#  94  var_95   24500 non-null  int64
#  95  var_96   24500 non-null  float64
#  96  var_97   24500 non-null  int64
#  97  var_98   24500 non-null  float64
#  98  var_99   24500 non-null  int64
#  99  var_100  24500 non-null  float64
# dtypes: float64(43), int64(57)
# memory usage: 18.9 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24500 entries, 10182 to 15687
# Data columns (total 100 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   var_101  24500 non-null  float64
#  1   var_102  24500 non-null  float64
#  2   var_103  24500 non-null  int64
#  3   var_104  24500 non-null  int64
#  4   var_105  24500 non-null  float64
#  5   var_106  24500 non-null  int64
#  6   var_107  24500 non-null  int64
#  7   var_108  24500 non-null  float64
#  8   var_109  24500 non-null  float64
#  9   var_110  24500 non-null  float64
#  10  var_111  24500 non-null  int64
#  11  var_112  24500 non-null  int64
#  12  var_113  24500 non-null  int64
#  13  var_114  24500 non-null  int64
#  14  var_115  24500 non-null  float64
#  15  var_116  24500 non-null  int64
#  16  var_117  24500 non-null  int64
#  17  var_118  24500 non-null  float64
#  18  var_119  24500 non-null  float64
#  19  var_120  24500 non-null  int64
#  20  var_121  24500 non-null  int64
#  21  var_122  24500 non-null  int64
#  22  var_123  24500 non-null  int64
#  23  var_124  24500 non-null  int64
#  24  var_125  24500 non-null  float64
#  25  var_126  24500 non-null  float64
#  26  var_127  24500 non-null  int64
#  27  var_128  24500 non-null  float64
#  28  var_129  24500 non-null  int64
#  29  var_130  24500 non-null  float64
#  30  var_131  24500 non-null  float64
#  31  var_132  24500 non-null  int64
#  32  var_133  24500 non-null  int64
#  33  var_134  24500 non-null  float64
#  34  var_135  24500 non-null  int64
#  35  var_136  24500 non-null  float64
#  36  var_137  24500 non-null  int64
#  37  var_138  24500 non-null  float64
#  38  var_139  24500 non-null  float64
#  39  var_140  24500 non-null  float64
#  40  var_141  24500 non-null  int64
#  41  var_142  24500 non-null  float64
#  42  var_143  24500 non-null  int64
#  43  var_144  24500 non-null  float64
#  44  var_145  24500 non-null  float64
#  45  var_146  24500 non-null  int64
#  46  var_147  24500 non-null  float64
#  47  var_148  24500 non-null  int64
#  48  var_149  24500 non-null  int64
#  49  var_150  24500 non-null  float64
#  50  var_151  24500 non-null  int64
#  51  var_152  24500 non-null  int64
#  52  var_153  24500 non-null  float64
#  53  var_154  24500 non-null  float64
#  54  var_155  24500 non-null  int64
#  55  var_156  24500 non-null  float64
#  56  var_157  24500 non-null  float64
#  57  var_158  24500 non-null  int64
#  58  var_159  24500 non-null  int64
#  59  var_160  24500 non-null  int64
#  60  var_161  24500 non-null  float64
#  61  var_162  24500 non-null  int64
#  62  var_163  24500 non-null  int64
#  63  var_164  24500 non-null  int64
#  64  var_165  24500 non-null  float64
#  65  var_166  24500 non-null  float64
#  66  var_167  24500 non-null  int64
#  67  var_168  24500 non-null  int64
#  68  var_169  24500 non-null  int64
#  69  var_170  24500 non-null  int64
#  70  var_171  24500 non-null  int64
#  71  var_172  24500 non-null  int64
#  72  var_173  24500 non-null  float64
#  73  var_174  24500 non-null  int64
#  74  var_175  24500 non-null  int64
#  75  var_176  24500 non-null  int64
#  76  var_177  24500 non-null  int64
#  77  var_178  24500 non-null  float64
#  78  var_179  24500 non-null  int64
#  79  var_180  24500 non-null  float64
#  80  var_181  24500 non-null  int64
#  81  var_182  24500 non-null  int64
#  82  var_183  24500 non-null  int64
#  83  var_184  24500 non-null  float64
#  84  var_185  24500 non-null  float64
#  85  var_186  24500 non-null  float64
#  86  var_187  24500 non-null  int64
#  87  var_188  24500 non-null  float64
#  88  var_189  24500 non-null  int64
#  89  var_190  24500 non-null  float64
#  90  var_191  24500 non-null  float64
#  91  var_192  24500 non-null  float64
#  92  var_193  24500 non-null  float64
#  93  var_194  24500 non-null  int64
#  94  var_195  24500 non-null  int64
#  95  var_196  24500 non-null  int64
#  96  var_197  24500 non-null  int64
#  97  var_198  24500 non-null  int64
#  98  var_199  24500 non-null  int64
#  99  var_200  24500 non-null  float64
# dtypes: float64(43), int64(57)
# memory usage: 18.9 MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24500 entries, 10182 to 15687
# Data columns (total 100 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   var_201  24500 non-null  int64
#  1   var_202  24500 non-null  int64
#  2   var_203  24500 non-null  float64
#  3   var_204  24500 non-null  float64
#  4   var_205  24500 non-null  float64
#  5   var_206  24500 non-null  int64
#  6   var_207  24500 non-null  float64
#  7   var_208  24500 non-null  float64
#  8   var_209  24500 non-null  int64
#  9   var_210  24500 non-null  float64
#  10  var_211  24500 non-null  int64
#  11  var_212  24500 non-null  int64
#  12  var_213  24500 non-null  float64
#  13  var_214  24500 non-null  float64
#  14  var_215  24500 non-null  int64
#  15  var_216  24500 non-null  int64
#  16  var_217  24500 non-null  int64
#  17  var_218  24500 non-null  int64
#  18  var_219  24500 non-null  int64
#  19  var_220  24500 non-null  float64
#  20  var_221  24500 non-null  int64
#  21  var_222  24500 non-null  float64
#  22  var_223  24500 non-null  int64
#  23  var_224  24500 non-null  int64
#  24  var_225  24500 non-null  int64
#  25  var_226  24500 non-null  int64
#  26  var_227  24500 non-null  float64
#  27  var_228  24500 non-null  float64
#  28  var_229  24500 non-null  int64
#  29  var_230  24500 non-null  int64
#  30  var_231  24500 non-null  float64
#  31  var_232  24500 non-null  int64
#  32  var_233  24500 non-null  int64
#  33  var_234  24500 non-null  int64
#  34  var_235  24500 non-null  int64
#  35  var_236  24500 non-null  int64
#  36  var_237  24500 non-null  float64
#  37  var_238  24500 non-null  int64
#  38  var_239  24500 non-null  int64
#  39  var_240  24500 non-null  float64
#  40  var_241  24500 non-null  int64
#  41  var_242  24500 non-null  float64
#  42  var_243  24500 non-null  float64
#  43  var_244  24500 non-null  float64
#  44  var_245  24500 non-null  int64
#  45  var_246  24500 non-null  float64
#  46  var_247  24500 non-null  int64
#  47  var_248  24500 non-null  int64
#  48  var_249  24500 non-null  int64
#  49  var_250  24500 non-null  int64
#  50  var_251  24500 non-null  int64
#  51  var_252  24500 non-null  int64
#  52  var_253  24500 non-null  float64
#  53  var_254  24500 non-null  float64
#  54  var_255  24500 non-null  float64
#  55  var_256  24500 non-null  int64
#  56  var_257  24500 non-null  float64
#  57  var_258  24500 non-null  int64
#  58  var_259  24500 non-null  int64
#  59  var_260  24500 non-null  int64
#  60  var_261  24500 non-null  float64
#  61  var_262  24500 non-null  int64
#  62  var_263  24500 non-null  int64
#  63  var_264  24500 non-null  float64
#  64  var_265  24500 non-null  float64
#  65  var_266  24500 non-null  float64
#  66  var_267  24500 non-null  int64
#  67  var_268  24500 non-null  float64
#  68  var_269  24500 non-null  int64
#  69  var_270  24500 non-null  int64
#  70  var_271  24500 non-null  float64
#  71  var_272  24500 non-null  float64
#  72  var_273  24500 non-null  int64
#  73  var_274  24500 non-null  int64
#  74  var_275  24500 non-null  int64
#  75  var_276  24500 non-null  float64
#  76  var_277  24500 non-null  float64
#  77  var_278  24500 non-null  int64
#  78  var_279  24500 non-null  float64
#  79  var_280  24500 non-null  float64
#  80  var_281  24500 non-null  int64
#  81  var_282  24500 non-null  int64
#  82  var_283  24500 non-null  float64
#  83  var_284  24500 non-null  int64
#  84  var_285  24500 non-null  int64
#  85  var_286  24500 non-null  float64
#  86  var_287  24500 non-null  int64
#  87  var_288  24500 non-null  float64
#  88  var_289  24500 non-null  int64
#  89  var_290  24500 non-null  float64
#  90  var_291  24500 non-null  int64
#  91  var_292  24500 non-null  float64
#  92  var_293  24500 non-null  int64
#  93  var_294  24500 non-null  int64
#  94  var_295  24500 non-null  int64
#  95  var_296  24500 non-null  int64
#  96  var_297  24500 non-null  int64
#  97  var_298  24500 non-null  int64
#  98  var_299  24500 non-null  float64
#  99  var_300  24500 non-null  float64
# dtypes: float64(41), int64(59)
# memory usage: 18.9 MB
# <class 'pandas.core.series.Series'>
# Int64Index: 24500 entries, 10182 to 15687
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 24500 non-null  int64
# dtypes: int64(1)
# memory usage: 382.8 KB
# 0    23560
# 1      940
# Name: target, dtype: int64

# %%
# odsetek 1 w zmiennej objaśnianej
df[df.target == 1].size/df.size
# Out:
# 0.03836734693877551

# %% [markdown]
# Wniosek: mamy do czynienia z 300 zmiennymi numerycznymi bez braków danych, a zmienna objaśniana jest binarna. Mamy ponadto do czynienia z dość niezbalansowanym zbiorem danych.

# %%
df.head(10)
# Out:
#        var_1  var_2  var_3  var_4  var_5  var_6  var_7  var_8  var_9  var_10  \
# 10182      0      0    0.0   5.94    0.0      0      0      0      0       0
# 33265      0      0    0.0   0.00    0.0      0      0      0      0       0
# 8751       0      0    0.0   5.64    0.0      0      0      0      0       0
# 3271       0      0    0.0   2.73    0.0      0      0      0      0       0
# 4666       0      0    0.0   0.00    0.0      0      0      0      0       0
# 10573      0      0    0.0   6.00    0.0      0      0      0      0       0
# 22670      0      0    0.0   5.70    0.0      0      0      0      0       0
# 4695       0      0    0.0   2.94    0.0      0      0      0      0       0
# 2267       0      0    0.0   2.94    0.0      0      0      0      0       0
# 37603      0      0    0.0   5.70    0.0      0      0      0      0       0
#
#        ...  var_292  var_293  var_294  var_295  var_296  var_297  var_298  \
# 10182  ...      0.0        0        0        0        0        0        0
# 33265  ...      0.0        0        0        0        0        0        0
# 8751   ...      0.0        0        0        0        0        0        0
# 3271   ...      0.0        0        0        0        0        0        0
# 4666   ...      0.0        0        0        0        0        0        0
# 10573  ...      0.0        0        0        0        0        0        0
# 22670  ...      0.0        0        0        0        0        0        0
# 4695   ...      0.0        0        0        0        0        0        0
# 2267   ...      0.0        0        0        0        0        0        0
# 37603  ...      0.0        0        0        3        0        0        0
#
#        var_299    var_300  target
# 10182      0.0       0.00       0
# 33265      0.0       0.00       0
# 8751       0.0       0.00       0
# 3271       0.0       0.00       0
# 4666       0.0       0.00       0
# 10573      0.0       0.00       0
# 22670      0.0       0.00       0
# 4695       0.0       0.00       0
# 2267       0.0       0.00       0
# 37603      0.0  215591.01       0
#
# [10 rows x 301 columns]

# %%
# rzucamy okiem na podsumowanie atrybutów numerycznych
df.describe()
# Out:
#               var_1    var_2          var_3         var_4          var_5  \
# count  24500.000000  24500.0   24500.000000  24500.000000   24500.000000
# mean       0.001959      0.0       9.505698      3.168856     576.883608
# std        0.101402      0.0     728.074414      2.768712   10151.771380
# min        0.000000      0.0       0.000000      0.000000       0.000000
# 25%        0.000000      0.0       0.000000      0.000000       0.000000
# 50%        0.000000      0.0       0.000000      2.850000       0.000000
# 75%        0.000000      0.0       0.000000      3.000000       0.000000
# max        9.000000      0.0  101195.473500     35.280000  418500.000000
#
#          var_6         var_7         var_8         var_9   var_10  ...  \
# count  24500.0  24500.000000  24500.000000  24500.000000  24500.0  ...
# mean       0.0      0.000122      0.032816      0.000367      0.0  ...
# std        0.0      0.019166      0.312051      0.033196      0.0  ...
# min        0.0      0.000000      0.000000      0.000000      0.0  ...
# 25%        0.0      0.000000      0.000000      0.000000      0.0  ...
# 50%        0.0      0.000000      0.000000      0.000000      0.0  ...
# 75%        0.0      0.000000      0.000000      0.000000      0.0  ...
# max        0.0      3.000000      3.000000      3.000000      0.0  ...
#
#            var_292       var_293  var_294       var_295       var_296  \
# count  24500.00000  24500.000000  24500.0  24500.000000  24500.000000
# mean       0.09703      0.009184      0.0      0.126000      0.085959
# std        1.26670      0.198049      0.0      0.604217      0.617478
# min        0.00000      0.000000      0.0      0.000000      0.000000
# 25%        0.00000      0.000000      0.0      0.000000      0.000000
# 50%        0.00000      0.000000      0.0      0.000000      0.000000
# 75%        0.00000      0.000000      0.0      0.000000      0.000000
# max       74.52000     12.000000      0.0      6.000000     27.000000
#
#        var_297       var_298        var_299       var_300        target
# count  24500.0  24500.000000   24500.000000  2.450000e+04  24500.000000
# mean       0.0      0.003143      17.845268  5.901528e+03      0.038367
# std        0.0      0.079991    1084.015022  4.991740e+04      0.192085
# min        0.0      0.000000       0.000000  0.000000e+00      0.000000
# 25%        0.0      0.000000       0.000000  0.000000e+00      0.000000
# 50%        0.0      0.000000       0.000000  0.000000e+00      0.000000
# 75%        0.0      0.000000       0.000000  0.000000e+00      0.000000
# max        0.0      3.000000  134666.681100  2.857673e+06      1.000000
#
# [8 rows x 301 columns]

# %% [markdown]
# Obserwujemy zmienne składające się w większości z zer z przeważnie bardzo dużą średnią i odchyleniem standardowym, w przewarzającej większości trzeci kwartyl jest zerem.

# %% [markdown]
# ## Analiza danych całkowitoliczbowych

# %%
df_integer = df.loc[:, df.dtypes == "int64"].copy()
df_integer.shape
# Out:
# (24500, 174)

# %%
# sprawdzamy liczbę unikalnych wartości w kolumnach
df_integer.nunique()
# Out:
# var_1      4
# var_2      1
# var_6      1
# var_7      2
# var_8      2
#           ..
# var_295    3
# var_296    7
# var_297    1
# var_298    4
# target     2
# Length: 174, dtype: int64

# %% [markdown]
# Sprawdzamy jakie wartości mają zmienne o typie całkowitoliczbowym

# %%
def show_variables(df):
    for column in df.columns:
        print(df[column].value_counts().reset_index())

show_variables(df_integer)
# Out:
#    index  var_1
# 0      0  24489
# 1      3      7
# 2      6      3
# 3      9      1
#    index  var_2
# 0      0  24500
#    index  var_6
# 0      0  24500
#    index  var_7
# 0      0  24499
# 1      3      1
#    index  var_8
# 0      0  24232
# 1      3    268
#    index  var_9
# 0      0  24497
# 1      3      3
#    index  var_10
# 0      0   24500
#    index  var_14
# 0      0   24500
#    index  var_15
# 0      3   16197
# 1      0    8241
# 2      6      61
# 3      9       1
#    index  var_19
# 0      0   24257
# 1      1     243
#    index  var_20
# 0      0   24496
# 1    450       1
# 2   1260       1
# 3    300       1
# 4    150       1
#    index  var_23
# 0      0   24500
#    index  var_24
# 0      0   24473
# 1      3      14
# 2      6       6
# 3      9       4
# 4     12       1
# 5     15       1
# 6     18       1
#    index  var_25
# 0      0   24368
# 1      3     118
# 2      6      10
# 3      9       2
# 4     12       1
# 5     24       1
#    index  var_28
# 0      0   24497
# 1      3       3
#    index  var_31
# 0      3   21102
# 1      0    2928
# 2      6     445
# 3      9      22
# 4     12       2
# 5     33       1
#    index  var_33
# 0      0   24500
#    index  var_34
# 0      0   24500
#    index  var_36
# 0      0   24500
#    index  var_37
# 0      0   23935
# 1      3     485
# 2      6      65
# 3      9      10
# 4     12       3
# 5     27       1
# 6     21       1
#    index  var_38
# 0      0   23577
# 1      3     923
#    index  var_43
# 0      0   24477
# 1      1      23
#    index  var_44
# 0      0   24500
#    index  var_45
# 0      0   24479
# 1      3      21
#    index  var_49
# 0     99    9685
# 1      3    7183
# 2      1    4693
# 3      2    2808
# 4      0     131
#    index  var_51
# 0      0   24252
# 1      3     193
# 2      6      40
# 3      9      10
# 4     12       3
# 5     15       2
#    index  var_52
# 0      0   23374
# 1      1    1126
#    index  var_53
# 0      0   24479
# 1      1      21
#    index  var_54
# 0      0   24252
# 1      1     248
#    index  var_56
# 0      0   24454
# 1      1      46
#    index  var_58
# 0      0   22841
# 1      3    1620
# 2      6      38
# 3     15       1
#    index  var_59
# 0      0   24493
# 1      3       4
# 2      6       2
# 3      9       1
#       index  var_60
# 0         0   24484
# 1  99999999      16
#    index  var_61
# 0      0   24500
#    index  var_62
# 0      3   20992
# 1      0    2894
# 2      6     579
# 3      9      32
# 4     12       2
# 5     33       1
#    index  var_63
# 0      0   24373
# 1      3     125
# 2     12       1
# 3      6       1
#    index  var_66
# 0      0   24500
#    index  var_67
# 0      0   24500
#    index  var_68
# 0      0   24333
# 1      3      89
# 2      2      62
# 3      1      16
#    index  var_69
# 0      0   24500
#    index  var_70
# 0      1   23485
# 1      0    1015
#    index  var_71
# 0      0   24499
# 1      1       1
#    index  var_72
# 0      0   24499
# 1  36000       1
#    index  var_73
# 0      0   24500
#    index  var_74
# 0      2   17630
# 1      1    3514
# 2      0    3252
# 3      3     104
#    index  var_80
# 0      0   24500
#    index  var_81
# 0      0   24500
#    index  var_82
# 0      0   21346
# 1      1    3154
#    index  var_83
# 0      0   22504
# 1      1    1996
#    index  var_84
# 0      0   24415
# 1      3      85
#    index  var_87
# 0      0   24500
#    index  var_88
# 0      0   23577
# 1      1     923
#    index  var_92
# 0      0   24500
#    index  var_94
# 0      0   24414
# 1      3      86
#    index  var_95
# 0      0   24488
# 1      3       6
# 2      6       4
# 3     21       1
# 4      9       1
#    index  var_97
# 0      0   24500
#    index  var_99
# 0      0   24500
#    index  var_103
# 0      0    23186
# 1      1     1314
#    index  var_104
# 0      0    24500
#    index  var_106
# 0      0    24477
# 1      1       23
#    index  var_107
# 0      3    22629
# 1      6     1684
# 2      0      141
# 3      9       42
# 4     12        3
# 5     18        1
#       index  var_111
# 0         0    24498
# 1  99999999        2
#    index  var_112
# 0      0    24500
#    index  var_113
# 0      0    24500
#    index  var_114
# 0      0    22841
# 1      1     1659
#    index  var_116
# 0      0    24499
# 1      3        1
#    index  var_117
# 0      0    23400
# 1      1     1100
#    index  var_120
# 0      0    24500
#    index  var_121
# 0      0    22235
# 1      1     2265
#    index  var_122
# 0      0    24500
#    index  var_123
# 0      0    23153
# 1      1     1347
#       index  var_124
# 0         0    24499
# 1  99999999        1
#    index  var_127
# 0      0    24500
#    index  var_129
# 0      0    24500
#    index  var_132
# 0      3    13837
# 1      0     6587
# 2      2     2989
# 3      1     1087
#    index  var_133
# 0      0    24500
#    index  var_135
# 0      0    24500
#    index  var_137
# 0      0    24403
# 1      1       97
#    index  var_141
# 0      0    24500
#    index  var_143
# 0      0    23914
# 1      3      498
# 2      6       73
# 3      9       10
# 4     12        3
# 5     27        1
# 6     21        1
#    index  var_146
# 0      0    24495
# 1      3        2
# 2      6        2
# 3      9        1
#    index  var_148
# 0      0    23935
# 1      3      485
# 2      6       65
# 3      9       10
# 4     12        3
# 5     27        1
# 6     21        1
#       index  var_149
# 0         0    24490
# 1  99999999       10
#    index  var_151
# 0      0    24500
#    index  var_152
# 0      1    17981
# 1      0     6519
#    index  var_155
# 0      0    23393
# 1      2      558
# 2      3      413
# 3      1      136
#    index  var_158
# 0      0    24500
#    index  var_159
# 0      0    24462
# 1      3       21
# 2      6       10
# 3      9        3
# 4     21        1
# 5     18        1
# 6     12        1
# 7     15        1
#    index  var_160
# 0      0    23186
# 1      3     1254
# 2      6       47
# 3      9        8
# 4     12        3
# 5     15        2
#    index  var_162
# 0      0    23410
# 1      1     1090
#    index  var_163
# 0      0    23153
# 1      3     1258
# 2      6       71
# 3      9       10
# 4     12        6
# 5     15        2
#    index  var_164
# 0      0    22123
# 1      1     2377
#    index  var_167
# 0      0    24500
#    index  var_168
# 0      0    23872
# 1      1      628
#    index  var_169
# 0      0    23811
# 1      2      291
# 2      1      251
# 3      3      147
#    index  var_170
# 0      0    24500
#    index  var_171
# 0      0    24500
#    index  var_172
# 0      0    24257
# 1      3      199
# 2      6       33
# 3      9        7
# 4     12        2
# 5     15        2
#    index  var_174
# 0      0    23920
# 1      3      577
# 2      6        2
# 3     12        1
#    index  var_175
# 0      1    21606
# 1      0     2894
#    index  var_176
# 0      0    23822
# 1      3      678
#    index  var_177
# 0      0    24415
# 1      1       85
#    index  var_179
# 0      1    21572
# 1      0     2928
#    index  var_181
# 0      0    23928
# 1      3      524
# 2      6       35
# 3      9        7
# 4     12        5
# 5     18        1
#    index  var_182
# 0      0    24500
#    index  var_183
# 0      0    24500
#    index  var_187
# 0      0    24499
# 1      3        1
#    index  var_189
# 0      0    24498
# 1      3        2
#    index  var_194
# 0      0    24443
# 1      1       57
#    index  var_195
# 0      0    24500
#    index  var_196
# 0      0    24500
#    index  var_197
# 0      0    24477
# 1      1       23
#    index  var_198
# 0      0    24414
# 1      1       86
#    index  var_199
# 0      0    24415
# 1      3       85
#    index  var_201
# 0      0    24500
#    index  var_202
# 0      0    24490
# 1      3        7
# 2      6        3
#    index  var_206
# 0      0    22903
# 1      1     1597
#    index  var_209
# 0      3    23326
# 1      0     1015
# 2      6      158
# 3      9        1
#    index  var_211
# 0      0    24477
# 1      3       17
# 2      6        6
#    index  var_212
# 0      0    24500
#    index  var_215
# 0      0    24500
#       index  var_216
# 0         0    24484
# 1  99999999       16
#       index  var_217
# 0         0    24499
# 1  99999999        1
#    index  var_218
# 0      0    24392
# 1      1      108
#    index  var_219
# 0      0    24476
# 1      1       24
#       index  var_221
# 0         0    24494
# 1  99999999        3
# 2        -1        3
#    index  var_223
# 0      0    24500
#    index  var_224
# 0      0    24470
# 1      3       20
# 2      6        7
# 3     15        1
# 4     12        1
# 5      9        1
#    index  var_225
# 0      0    24500
#    index  var_226
# 0      0    22874
# 1      1     1626
#    index  var_229
# 0      0    23914
# 1      1      586
#    index  var_230
# 0      3    16617
# 1      0     6519
# 2      6     1238
# 3      9      105
# 4     12       15
# 5     15        4
# 6     33        1
# 7     18        1
#    index  var_232
# 0      0    22874
# 1      1     1626
#    index  var_233
# 0      0    24499
# 1      1        1
#    index  var_234
# 0      0    24500
#    index  var_235
# 0      0    24484
# 1      3       16
#    index  var_236
# 0      0    24458
# 1      3       42
#    index  var_238
# 0      0    24443
# 1      3       57
#       index  var_239
# 0         0    24490
# 1  99999999       10
#    index  var_241
# 0      0    23707
# 1      1      793
#    index  var_245
# 0      0    24457
# 1      1       43
#    index  var_247
# 0      0    24499
# 1      3        1
#    index  var_248
# 0      0    24500
#    index  var_249
# 0      0    24458
# 1      1       42
#    index  var_250
# 0      0    24415
# 1      1       85
#    index  var_251
# 0      0    24454
# 1      1       18
# 2      2       17
# 3      3       11
#    index  var_252
# 0      0    22384
# 1      1     2116
#    index  var_256
# 0      0    24399
# 1      1      101
#    index  var_258
# 0      0    23410
# 1      3     1090
#    index  var_259
# 0      0    23400
# 1      3     1092
# 2      6        7
# 3     15        1
#    index  var_260
# 0      0    24479
# 1      2       11
# 2      3        6
# 3      1        4
#    index  var_262
# 0      1    12274
# 1      0     6265
# 2      2     4097
# 3      3     1475
# 4      4      302
# 5      5       72
# 6      6       13
# 7      7        2
#       index  var_263
# 0         0    24494
# 1  99999999        3
# 2        -1        3
#    index  var_267
# 0      0    24496
# 1      3        4
#    index  var_269
# 0      0    23914
# 1      1      586
#    index  var_270
# 0      0    23935
# 1      1      565
#    index  var_273
# 0      0    24403
# 1      3       78
# 2      6       10
# 3      9        5
# 4     21        1
# 5     18        1
# 6     12        1
# 7     15        1
#    index  var_274
# 0      0    24494
# 1      3        6
#    index  var_275
# 0      0    23920
# 1      1      580
#    index  var_278
# 0      0    24413
# 1      3       87
#    index  var_281
# 0      0    24232
# 1      1      268
#    index  var_282
# 0      0    24462
# 1      1       38
#    index  var_284
# 0      0    23475
# 1      1     1025
#    index  var_285
# 0      0    24499
# 1      3        1
#    index  var_287
# 0      0    24500
#    index  var_289
# 0      0    24499
# 1      1        1
#    index  var_291
# 0      0    24454
# 1      3       46
#    index  var_293
# 0      0    24436
# 1      3       57
# 2      6        4
# 3      9        2
# 4     12        1
#    index  var_294
# 0      0    24500
#    index  var_295
# 0      0    23475
# 1      3     1021
# 2      6        4
#    index  var_296
# 0      0    23914
# 1      3      498
# 2      6       73
# 3      9       10
# 4     12        3
# 5     27        1
# 6     21        1
#    index  var_297
# 0      0    24500
#    index  var_298
# 0      0    24458
# 1      2       25
# 2      1       12
# 3      3        5
#    index  target
# 0      0   23560
# 1      1     940

# %% [markdown]
# Wnioski: istnieje bardzo wiele kolumn składających się praktycznie z jednej wartości, ponadto mogą istnieć zdublowane kolumny, kolumny o typie całkowitoliczbowym składają się zazwyczaj z niewielkiego zbioru wartości i często są binarne.
#
# Mamy podejrzenie, że wartości w kolumnach całkowitoliczbowych reprezentują pewne kategorie. Będziemy potem kodować je za pomocą one hot encodera.

# %%
# poniższa funkcja podaje kolumny z df, które składają się w percent% z jednej wartości
def find_constant_columns(df, percent):

    res = []
    for column in df.columns:
        if df[column].value_counts(normalize=True).iloc[0] >= percent/100:
            res.append(column)
    return res

# poniższa funkcja usuwa znalezione powyżej kolumny
def delete_constant_columns(df, percent):
    before = df.shape[1]
    df.drop(df.loc[:, find_constant_columns(df, percent)], axis=1, inplace=True)
    after = df.shape[1]
    print(f"Usunięto {before - after} kolumn, pozostało {after}.")

# %% [markdown]
# Usuwamy stałe i prawie stałe kolumny

# %%
print(find_constant_columns(df_integer, 99.99))
delete_constant_columns(df_integer, 99.99)
# Out:
# ['var_2', 'var_6', 'var_7', 'var_10', 'var_14', 'var_23', 'var_33', 'var_34', 'var_36', 'var_44', 'var_61', 'var_66', 'var_67', 'var_69', 'var_71', 'var_72', 'var_73', 'var_80', 'var_81', 'var_87', 'var_92', 'var_97', 'var_99', 'var_104', 'var_111', 'var_112', 'var_113', 'var_116', 'var_120', 'var_122', 'var_124', 'var_127', 'var_129', 'var_133', 'var_135', 'var_141', 'var_151', 'var_158', 'var_167', 'var_170', 'var_171', 'var_182', 'var_183', 'var_187', 'var_189', 'var_195', 'var_196', 'var_201', 'var_212', 'var_215', 'var_217', 'var_223', 'var_225', 'var_233', 'var_234', 'var_247', 'var_248', 'var_285', 'var_287', 'var_289', 'var_294', 'var_297']
# Usunięto 62 kolumn, pozostało 112.

# %% [markdown]
# Usuwamy ewentualne zduplikowane kolumny

# %%
def find_duplicated_columns(df):
    return df.loc[:, df.T.duplicated()].columns.tolist()

def delete_duplicated_columns(df):
    before = df.shape[1]
    df.drop(df.loc[:, df.T.duplicated()], axis=1, inplace=True)
    after = df.shape[1]
    print(f"Usunięto {before - after} kolumn, pozostało {after}.")

# %%
print(find_duplicated_columns(df_integer))
delete_duplicated_columns(df_integer)
# Out:
# ['var_106', 'var_148', 'var_197', 'var_199', 'var_216', 'var_232', 'var_239', 'var_250', 'var_263', 'var_269', 'var_296']
# Usunięto 11 kolumn, pozostało 101.

# %%
# poniższa funkcja podaje kolumny z [data], które są w [percent]% zależne od innej kolumny (spośród pary skorelowanych kolumn podawana jest jedna)
def find_corelated_columns(data, percent,mark):

    ### mark = 1 dla float
    ### cokolwiek dla pseudodyskretnych
    
    if(mark == 1):
        corr = data.corr(method='pearson')
    else:
        corr = data.corr(method='spearman')
    corr = corr[corr > percent/100]

    dependent_columns = corr.apply(lambda row: row[row > 0].index, axis=1)
    res = []
    for j in range (len(dependent_columns)):
        for k in dependent_columns[j]:
            if k is not dependent_columns.index[j]:
                if k not in dependent_columns.index[0:j]:
                    res.append(k)

    return np.unique(np.array(res))

def delete_corelated_columns(df, percent,mark):
    before = df.shape[1]
    df.drop(find_corelated_columns(df, percent,mark), axis=1, inplace=True)
    after = df.shape[1]
    print(f"Usunięto {before - after} kolumn, pozostało {after}.")

# %% [markdown]
# Usuwamy kolumny wysoce skorelowane z innymi

# %%
print(find_corelated_columns(df_integer, 99.99,-1))
delete_corelated_columns(df_integer, 99.99,-1)
# Out:
# ['var_114' 'var_160' 'var_163' 'var_172' 'var_177' 'var_198' 'var_211'
#  'var_229' 'var_235' 'var_238' 'var_249' 'var_251' 'var_258' 'var_259'
#  'var_260' 'var_267' 'var_270' 'var_273' 'var_275' 'var_281' 'var_282'
#  'var_291' 'var_295' 'var_53' 'var_54' 'var_88']
# Usunięto 26 kolumn, pozostało 75.

# %% [markdown]
# Sprawdzamy jak teraz prezentują się wartości w zmiennych całkowitoliczbowych

# %%
show_variables(df_integer)
# Out:
#    index  var_1
# 0      0  24489
# 1      3      7
# 2      6      3
# 3      9      1
#    index  var_8
# 0      0  24232
# 1      3    268
#    index  var_9
# 0      0  24497
# 1      3      3
#    index  var_15
# 0      3   16197
# 1      0    8241
# 2      6      61
# 3      9       1
#    index  var_19
# 0      0   24257
# 1      1     243
#    index  var_20
# 0      0   24496
# 1    450       1
# 2   1260       1
# 3    300       1
# 4    150       1
#    index  var_24
# 0      0   24473
# 1      3      14
# 2      6       6
# 3      9       4
# 4     12       1
# 5     15       1
# 6     18       1
#    index  var_25
# 0      0   24368
# 1      3     118
# 2      6      10
# 3      9       2
# 4     12       1
# 5     24       1
#    index  var_28
# 0      0   24497
# 1      3       3
#    index  var_31
# 0      3   21102
# 1      0    2928
# 2      6     445
# 3      9      22
# 4     12       2
# 5     33       1
#    index  var_37
# 0      0   23935
# 1      3     485
# 2      6      65
# 3      9      10
# 4     12       3
# 5     27       1
# 6     21       1
#    index  var_38
# 0      0   23577
# 1      3     923
#    index  var_43
# 0      0   24477
# 1      1      23
#    index  var_45
# 0      0   24479
# 1      3      21
#    index  var_49
# 0     99    9685
# 1      3    7183
# 2      1    4693
# 3      2    2808
# 4      0     131
#    index  var_51
# 0      0   24252
# 1      3     193
# 2      6      40
# 3      9      10
# 4     12       3
# 5     15       2
#    index  var_52
# 0      0   23374
# 1      1    1126
#    index  var_56
# 0      0   24454
# 1      1      46
#    index  var_58
# 0      0   22841
# 1      3    1620
# 2      6      38
# 3     15       1
#    index  var_59
# 0      0   24493
# 1      3       4
# 2      6       2
# 3      9       1
#       index  var_60
# 0         0   24484
# 1  99999999      16
#    index  var_62
# 0      3   20992
# 1      0    2894
# 2      6     579
# 3      9      32
# 4     12       2
# 5     33       1
#    index  var_63
# 0      0   24373
# 1      3     125
# 2     12       1
# 3      6       1
#    index  var_68
# 0      0   24333
# 1      3      89
# 2      2      62
# 3      1      16
#    index  var_70
# 0      1   23485
# 1      0    1015
#    index  var_74
# 0      2   17630
# 1      1    3514
# 2      0    3252
# 3      3     104
#    index  var_82
# 0      0   21346
# 1      1    3154
#    index  var_83
# 0      0   22504
# 1      1    1996
#    index  var_84
# 0      0   24415
# 1      3      85
#    index  var_94
# 0      0   24414
# 1      3      86
#    index  var_95
# 0      0   24488
# 1      3       6
# 2      6       4
# 3     21       1
# 4      9       1
#    index  var_103
# 0      0    23186
# 1      1     1314
#    index  var_107
# 0      3    22629
# 1      6     1684
# 2      0      141
# 3      9       42
# 4     12        3
# 5     18        1
#    index  var_117
# 0      0    23400
# 1      1     1100
#    index  var_121
# 0      0    22235
# 1      1     2265
#    index  var_123
# 0      0    23153
# 1      1     1347
#    index  var_132
# 0      3    13837
# 1      0     6587
# 2      2     2989
# 3      1     1087
#    index  var_137
# 0      0    24403
# 1      1       97
#    index  var_143
# 0      0    23914
# 1      3      498
# 2      6       73
# 3      9       10
# 4     12        3
# 5     27        1
# 6     21        1
#    index  var_146
# 0      0    24495
# 1      3        2
# 2      6        2
# 3      9        1
#       index  var_149
# 0         0    24490
# 1  99999999       10
#    index  var_152
# 0      1    17981
# 1      0     6519
#    index  var_155
# 0      0    23393
# 1      2      558
# 2      3      413
# 3      1      136
#    index  var_159
# 0      0    24462
# 1      3       21
# 2      6       10
# 3      9        3
# 4     21        1
# 5     18        1
# 6     12        1
# 7     15        1
#    index  var_162
# 0      0    23410
# 1      1     1090
#    index  var_164
# 0      0    22123
# 1      1     2377
#    index  var_168
# 0      0    23872
# 1      1      628
#    index  var_169
# 0      0    23811
# 1      2      291
# 2      1      251
# 3      3      147
#    index  var_174
# 0      0    23920
# 1      3      577
# 2      6        2
# 3     12        1
#    index  var_175
# 0      1    21606
# 1      0     2894
#    index  var_176
# 0      0    23822
# 1      3      678
#    index  var_179
# 0      1    21572
# 1      0     2928
#    index  var_181
# 0      0    23928
# 1      3      524
# 2      6       35
# 3      9        7
# 4     12        5
# 5     18        1
#    index  var_194
# 0      0    24443
# 1      1       57
#    index  var_202
# 0      0    24490
# 1      3        7
# 2      6        3
#    index  var_206
# 0      0    22903
# 1      1     1597
#    index  var_209
# 0      3    23326
# 1      0     1015
# 2      6      158
# 3      9        1
#    index  var_218
# 0      0    24392
# 1      1      108
#    index  var_219
# 0      0    24476
# 1      1       24
#       index  var_221
# 0         0    24494
# 1  99999999        3
# 2        -1        3
#    index  var_224
# 0      0    24470
# 1      3       20
# 2      6        7
# 3     15        1
# 4     12        1
# 5      9        1
#    index  var_226
# 0      0    22874
# 1      1     1626
#    index  var_230
# 0      3    16617
# 1      0     6519
# 2      6     1238
# 3      9      105
# 4     12       15
# 5     15        4
# 6     33        1
# 7     18        1
#    index  var_236
# 0      0    24458
# 1      3       42
#    index  var_241
# 0      0    23707
# 1      1      793
#    index  var_245
# 0      0    24457
# 1      1       43
#    index  var_252
# 0      0    22384
# 1      1     2116
#    index  var_256
# 0      0    24399
# 1      1      101
#    index  var_262
# 0      1    12274
# 1      0     6265
# 2      2     4097
# 3      3     1475
# 4      4      302
# 5      5       72
# 6      6       13
# 7      7        2
#    index  var_274
# 0      0    24494
# 1      3        6
#    index  var_278
# 0      0    24413
# 1      3       87
#    index  var_284
# 0      0    23475
# 1      1     1025
#    index  var_293
# 0      0    24436
# 1      3       57
# 2      6        4
# 3      9        2
# 4     12        1
#    index  var_298
# 0      0    24458
# 1      2       25
# 2      1       12
# 3      3        5
#    index  target
# 0      0   23560
# 1      1     940

# %% [markdown]
# Jak wartości ze zmiennych całkowitoliczbowych mają się do zmiennej target?

# %%
def show_dependencies(df):
    for column in df.columns:
        print(df.groupby(column)['target'].agg(['sum','count']).sort_values('sum',ascending = False))

# %%
show_dependencies(df_integer)
# Out:
#        sum  count
# var_1
# 0      940  24489
# 3        0      7
# 6        0      3
# 9        0      1
#        sum  count
# var_8
# 0      936  24232
# 3        4    268
#        sum  count
# var_9
# 0      940  24497
# 3        0      3
#         sum  count
# var_15
# 0       617   8241
# 3       321  16197
# 6         2     61
# 9         0      1
#         sum  count
# var_19
# 0       939  24257
# 1         1    243
#         sum  count
# var_20
# 0       940  24496
# 150       0      1
# 300       0      1
# 450       0      1
# 1260      0      1
#         sum  count
# var_24
# 0       940  24473
# 3         0     14
# 6         0      6
# 9         0      4
# 12        0      1
# 15        0      1
# 18        0      1
#         sum  count
# var_25
# 0       936  24368
# 3         4    118
# 6         0     10
# 9         0      2
# 12        0      1
# 24        0      1
#         sum  count
# var_28
# 0       940  24497
# 3         0      3
#         sum  count
# var_31
# 3       755  21102
# 0       164   2928
# 6        20    445
# 9         1     22
# 12        0      2
# 33        0      1
#         sum  count
# var_37
# 0       904  23935
# 3        33    485
# 6         3     65
# 9         0     10
# 12        0      3
# 21        0      1
# 27        0      1
#         sum  count
# var_38
# 0       935  23577
# 3         5    923
#         sum  count
# var_43
# 0       940  24477
# 1         0     23
#         sum  count
# var_45
# 0       940  24479
# 3         0     21
#         sum  count
# var_49
# 99      612   9685
# 1       145   4693
# 3       106   7183
# 2        77   2808
# 0         0    131
#         sum  count
# var_51
# 0       939  24252
# 3         1    193
# 6         0     40
# 9         0     10
# 12        0      3
# 15        0      2
#         sum  count
# var_52
# 0       931  23374
# 1         9   1126
#         sum  count
# var_56
# 0       940  24454
# 1         0     46
#         sum  count
# var_58
# 0       928  22841
# 3        12   1620
# 6         0     38
# 15        0      1
#         sum  count
# var_59
# 0       940  24493
# 3         0      4
# 6         0      2
# 9         0      1
#           sum  count
# var_60
# 0         940  24484
# 99999999    0     16
#         sum  count
# var_62
# 3       754  20992
# 0       164   2894
# 6        21    579
# 9         1     32
# 12        0      2
# 33        0      1
#         sum  count
# var_63
# 0       938  24373
# 3         2    125
# 6         0      1
# 12        0      1
#         sum  count
# var_68
# 0       940  24333
# 1         0     16
# 2         0     62
# 3         0     89
#         sum  count
# var_70
# 1       871  23485
# 0        69   1015
#         sum  count
# var_74
# 2       695  17630
# 0       177   3252
# 1        65   3514
# 3         3    104
#         sum  count
# var_82
# 0       847  21346
# 1        93   3154
#         sum  count
# var_83
# 0       855  22504
# 1        85   1996
#         sum  count
# var_84
# 0       938  24415
# 3         2     85
#         sum  count
# var_94
# 0       938  24414
# 3         2     86
#         sum  count
# var_95
# 0       938  24488
# 3         1      6
# 6         1      4
# 9         0      1
# 21        0      1
#          sum  count
# var_103
# 0        930  23186
# 1         10   1314
#          sum  count
# var_107
# 3        917  22629
# 6         23   1684
# 0          0    141
# 9          0     42
# 12         0      3
# 18         0      1
#          sum  count
# var_117
# 0        933  23400
# 1          7   1100
#          sum  count
# var_121
# 0        847  22235
# 1         93   2265
#          sum  count
# var_123
# 0        930  23153
# 1         10   1347
#          sum  count
# var_132
# 0        557   6587
# 3        242  13837
# 2         97   2989
# 1         44   1087
#          sum  count
# var_137
# 0        939  24403
# 1          1     97
#          sum  count
# var_143
# 0        904  23914
# 3         33    498
# 6          3     73
# 9          0     10
# 12         0      3
# 21         0      1
# 27         0      1
#          sum  count
# var_146
# 0        940  24495
# 3          0      2
# 6          0      2
# 9          0      1
#           sum  count
# var_149
# 0         939  24490
# 99999999    1     10
#          sum  count
# var_152
# 0        565   6519
# 1        375  17981
#          sum  count
# var_155
# 0        931  23393
# 3          4    413
# 1          3    136
# 2          2    558
#          sum  count
# var_159
# 0        939  24462
# 18         1      1
# 3          0     21
# 6          0     10
# 9          0      3
# 12         0      1
# 15         0      1
# 21         0      1
#          sum  count
# var_162
# 0        931  23410
# 1          9   1090
#          sum  count
# var_164
# 0        846  22123
# 1         94   2377
#          sum  count
# var_168
# 0        897  23872
# 1         43    628
#          sum  count
# var_169
# 0        890  23811
# 2         26    291
# 1         18    251
# 3          6    147
#          sum  count
# var_174
# 0        936  23920
# 3          4    577
# 6          0      2
# 12         0      1
#          sum  count
# var_175
# 1        776  21606
# 0        164   2894
#          sum  count
# var_176
# 0        893  23822
# 3         47    678
#          sum  count
# var_179
# 1        776  21572
# 0        164   2928
#          sum  count
# var_181
# 0        939  23928
# 3          1    524
# 6          0     35
# 9          0      7
# 12         0      5
# 18         0      1
#          sum  count
# var_194
# 0        940  24443
# 1          0     57
#          sum  count
# var_202
# 0        938  24490
# 3          1      7
# 6          1      3
#          sum  count
# var_206
# 0        888  22903
# 1         52   1597
#          sum  count
# var_209
# 3        861  23326
# 0         69   1015
# 6         10    158
# 9          0      1
#          sum  count
# var_218
# 0        939  24392
# 1          1    108
#          sum  count
# var_219
# 0        940  24476
# 1          0     24
#            sum  count
# var_221
#  0         940  24494
# -1           0      3
#  99999999    0      3
#          sum  count
# var_224
# 0        937  24470
# 3          2     20
# 6          1      7
# 9          0      1
# 12         0      1
# 15         0      1
#          sum  count
# var_226
# 0        881  22874
# 1         59   1626
#          sum  count
# var_230
# 0        565   6519
# 3        361  16617
# 6         14   1238
# 9          0    105
# 12         0     15
# 15         0      4
# 18         0      1
# 33         0      1
#          sum  count
# var_236
# 0        940  24458
# 3          0     42
#          sum  count
# var_241
# 0        870  23707
# 1         70    793
#          sum  count
# var_245
# 0        939  24457
# 1          1     43
#          sum  count
# var_252
# 0        854  22384
# 1         86   2116
#          sum  count
# var_256
# 0        940  24399
# 1          0    101
#          sum  count
# var_262
# 0        549   6265
# 1        216  12274
# 2        102   4097
# 3         60   1475
# 4         13    302
# 5          0     72
# 6          0     13
# 7          0      2
#          sum  count
# var_274
# 0        940  24494
# 3          0      6
#          sum  count
# var_278
# 0        940  24413
# 3          0     87
#          sum  count
# var_284
# 0        932  23475
# 1          8   1025
#          sum  count
# var_293
# 0        937  24436
# 3          3     57
# 6          0      4
# 9          0      2
# 12         0      1
#          sum  count
# var_298
# 0        939  24458
# 1          1     12
# 2          0     25
# 3          0      5
#         sum  count
# target
# 1       940    940
# 0         0  23560

# %% [markdown]
# Obserwujemy że występują kolumny, w których cała informacja o jedynkach jest niesiona przez wartość 0. Znajdźmy i zlikwidujmy je.

# %%
def find_not_informational_columns(df, x):
    amount_of_ones = df[df.target == 1].shape[0]
    res = []
    for column in df.columns:
        tmp = df.groupby(column)['target'].agg(['sum','count']).sort_values('sum',ascending = False).reset_index()
        if any(tmp[column] == 0) and (tmp.loc[tmp[column] == 0, 'sum'] >= amount_of_ones - x).bool():
            res.append(column)
    return res

def delete_not_informational_columns(df, x):
    before = df.shape[1]
    df.drop(find_not_informational_columns(df, x), axis=1, inplace=True)
    after = df.shape[1]
    print(f"Usunięto {before - after} kolumn, pozostało {after}.")

# %%
print(find_not_informational_columns(df_integer, 1))
delete_not_informational_columns(df_integer, 1)
# Out:
# ['var_1', 'var_9', 'var_19', 'var_20', 'var_24', 'var_28', 'var_43', 'var_45', 'var_51', 'var_56', 'var_59', 'var_60', 'var_68', 'var_137', 'var_146', 'var_149', 'var_159', 'var_181', 'var_194', 'var_218', 'var_219', 'var_221', 'var_236', 'var_245', 'var_256', 'var_274', 'var_278', 'var_298']
# Usunięto 28 kolumn, pozostało 47.

# %%
show_dependencies(df_integer)
# Out:
#        sum  count
# var_8
# 0      936  24232
# 3        4    268
#         sum  count
# var_15
# 0       617   8241
# 3       321  16197
# 6         2     61
# 9         0      1
#         sum  count
# var_25
# 0       936  24368
# 3         4    118
# 6         0     10
# 9         0      2
# 12        0      1
# 24        0      1
#         sum  count
# var_31
# 3       755  21102
# 0       164   2928
# 6        20    445
# 9         1     22
# 12        0      2
# 33        0      1
#         sum  count
# var_37
# 0       904  23935
# 3        33    485
# 6         3     65
# 9         0     10
# 12        0      3
# 21        0      1
# 27        0      1
#         sum  count
# var_38
# 0       935  23577
# 3         5    923
#         sum  count
# var_49
# 99      612   9685
# 1       145   4693
# 3       106   7183
# 2        77   2808
# 0         0    131
#         sum  count
# var_52
# 0       931  23374
# 1         9   1126
#         sum  count
# var_58
# 0       928  22841
# 3        12   1620
# 6         0     38
# 15        0      1
#         sum  count
# var_62
# 3       754  20992
# 0       164   2894
# 6        21    579
# 9         1     32
# 12        0      2
# 33        0      1
#         sum  count
# var_63
# 0       938  24373
# 3         2    125
# 6         0      1
# 12        0      1
#         sum  count
# var_70
# 1       871  23485
# 0        69   1015
#         sum  count
# var_74
# 2       695  17630
# 0       177   3252
# 1        65   3514
# 3         3    104
#         sum  count
# var_82
# 0       847  21346
# 1        93   3154
#         sum  count
# var_83
# 0       855  22504
# 1        85   1996
#         sum  count
# var_84
# 0       938  24415
# 3         2     85
#         sum  count
# var_94
# 0       938  24414
# 3         2     86
#         sum  count
# var_95
# 0       938  24488
# 3         1      6
# 6         1      4
# 9         0      1
# 21        0      1
#          sum  count
# var_103
# 0        930  23186
# 1         10   1314
#          sum  count
# var_107
# 3        917  22629
# 6         23   1684
# 0          0    141
# 9          0     42
# 12         0      3
# 18         0      1
#          sum  count
# var_117
# 0        933  23400
# 1          7   1100
#          sum  count
# var_121
# 0        847  22235
# 1         93   2265
#          sum  count
# var_123
# 0        930  23153
# 1         10   1347
#          sum  count
# var_132
# 0        557   6587
# 3        242  13837
# 2         97   2989
# 1         44   1087
#          sum  count
# var_143
# 0        904  23914
# 3         33    498
# 6          3     73
# 9          0     10
# 12         0      3
# 21         0      1
# 27         0      1
#          sum  count
# var_152
# 0        565   6519
# 1        375  17981
#          sum  count
# var_155
# 0        931  23393
# 3          4    413
# 1          3    136
# 2          2    558
#          sum  count
# var_162
# 0        931  23410
# 1          9   1090
#          sum  count
# var_164
# 0        846  22123
# 1         94   2377
#          sum  count
# var_168
# 0        897  23872
# 1         43    628
#          sum  count
# var_169
# 0        890  23811
# 2         26    291
# 1         18    251
# 3          6    147
#          sum  count
# var_174
# 0        936  23920
# 3          4    577
# 6          0      2
# 12         0      1
#          sum  count
# var_175
# 1        776  21606
# 0        164   2894
#          sum  count
# var_176
# 0        893  23822
# 3         47    678
#          sum  count
# var_179
# 1        776  21572
# 0        164   2928
#          sum  count
# var_202
# 0        938  24490
# 3          1      7
# 6          1      3
#          sum  count
# var_206
# 0        888  22903
# 1         52   1597
#          sum  count
# var_209
# 3        861  23326
# 0         69   1015
# 6         10    158
# 9          0      1
#          sum  count
# var_224
# 0        937  24470
# 3          2     20
# 6          1      7
# 9          0      1
# 12         0      1
# 15         0      1
#          sum  count
# var_226
# 0        881  22874
# 1         59   1626
#          sum  count
# var_230
# 0        565   6519
# 3        361  16617
# 6         14   1238
# 9          0    105
# 12         0     15
# 15         0      4
# 18         0      1
# 33         0      1
#          sum  count
# var_241
# 0        870  23707
# 1         70    793
#          sum  count
# var_252
# 0        854  22384
# 1         86   2116
#          sum  count
# var_262
# 0        549   6265
# 1        216  12274
# 2        102   4097
# 3         60   1475
# 4         13    302
# 5          0     72
# 6          0     13
# 7          0      2
#          sum  count
# var_284
# 0        932  23475
# 1          8   1025
#          sum  count
# var_293
# 0        937  24436
# 3          3     57
# 6          0      4
# 9          0      2
# 12         0      1
#         sum  count
# target
# 1       940    940
# 0         0  23560

# %% [markdown]
# Powyższymi zabiegami zredukowaliśmy liczbę kolumn całkowitoliczbowych z 174 do 55, oczywiście liczba ta wzrośnie, kiedy będziemy chcieli je zakodować za pomocą one hot encodera.

# %% [markdown]
# ## Analiza danych zmiennoprzecinkowych

# %%
df_float = df.loc[:, df.dtypes == "float64"].copy()
df_float = df_float.join(df.target)
df_float.shape
# Out:
# (24500, 128)

# %%
df_float.describe()
# Out:
#                var_3         var_4          var_5   var_11   var_12  \
# count   24500.000000  24500.000000   24500.000000  24500.0  24500.0
# mean        9.505698      3.168856     576.883608      0.0      0.0
# std       728.074414      2.768712   10151.771380      0.0      0.0
# min         0.000000      0.000000       0.000000      0.0      0.0
# 25%         0.000000      0.000000       0.000000      0.0      0.0
# 50%         0.000000      2.850000       0.000000      0.0      0.0
# 75%         0.000000      3.000000       0.000000      0.0      0.0
# max    101195.473500     35.280000  418500.000000      0.0      0.0
#
#              var_13         var_16        var_17         var_18  \
# count  24500.000000   24500.000000  24500.000000   24500.000000
# mean       5.049415      56.243582      1.147002     104.985083
# std      231.507148    2878.129876      3.120918    1902.742951
# min       -0.900000       0.000000      0.000000    -685.475100
# 25%        0.000000       0.000000      0.000000       0.000000
# 50%        0.000000       0.000000      0.000000       0.000000
# 75%        0.000000       0.000000      0.000000       0.000000
# max    33120.000000  377990.085000     49.980000  158256.974400
#
#               var_21  ...       var_279  var_280  var_283        var_286  \
# count   24500.000000  ...  24500.000000  24500.0  24500.0   24500.000000
# mean     1035.879430  ...      2.799549      0.0      0.0      82.450338
# std      9442.807758  ...     10.460820      0.0      0.0    3153.057895
# min      -464.544000  ...      0.000000      0.0      0.0       0.000000
# 25%         0.000000  ...      0.000000      0.0      0.0       0.000000
# 50%         2.910000  ...      0.000000      0.0      0.0       0.000000
# 75%        86.400000  ...      0.000000      0.0      0.0       0.000000
# max    552414.000000  ...    253.800000      0.0      0.0  246477.390600
#
#             var_288       var_290      var_292        var_299       var_300  \
# count  24500.000000  24500.000000  24500.00000   24500.000000  2.450000e+04
# mean       0.110804     10.246986      0.09703      17.845268  5.901528e+03
# std        1.083260    533.527182      1.26670    1084.015022  4.991740e+04
# min        0.000000      0.000000      0.00000       0.000000  0.000000e+00
# 25%        0.000000      0.000000      0.00000       0.000000  0.000000e+00
# 50%        0.000000      0.000000      0.00000       0.000000  0.000000e+00
# 75%        0.000000      0.000000      0.00000       0.000000  0.000000e+00
# max       41.850000  45503.530800     74.52000  134666.681100  2.857673e+06
#
#              target
# count  24500.000000
# mean       0.038367
# std        0.192085
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 128 columns]

# %% [markdown]
# Sprawdzamy rozkłady zmiennych o typie zmiennoprzecinkowym

# %%
# for column in df_float.columns:
#     df_float[column].hist(bins=10, figsize=(5, 2))
#     plt.show()

# %% [markdown]
# Wniosek: kolumny o wartościach zmiennoprzecinkowych składają się głównie z samych 0 i mają dość nietypowe rozkłady

# %% [markdown]
# Korzystając ze zdefiniowanych funkcji usuwamy stałe i prawie stałe kolumny, zduplikowane kolumny, zależne od innych i nie niosące informacji o 1

# %%
delete_duplicated_columns(df_float)
delete_constant_columns(df_float, 99.99)
delete_corelated_columns(df_float, 99.99,1)
delete_not_informational_columns(df_float, 10)
# Out:
# Usunięto 10 kolumn, pozostało 118.
# Usunięto 4 kolumn, pozostało 114.
# Usunięto 1 kolumn, pozostało 113.
# Usunięto 57 kolumn, pozostało 56.

# %% [markdown]
# Łączymy ramki danych float i int

# %%
df_float.drop('target', axis=1, inplace=True)
df = df_integer.join(df_float)
df.shape
# Out:
# (24500, 102)

# %%
df.describe()
# Out:
#               var_8        var_15        var_25        var_31        var_37  \
# count  24500.000000  24500.000000  24500.000000  24500.000000  24500.000000
# mean       0.032816      1.998612      0.019102      2.703306      0.082408
# std        0.312051      1.431255      0.306071      1.107591      0.604439
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      3.000000      0.000000
# 50%        0.000000      3.000000      0.000000      3.000000      0.000000
# 75%        0.000000      3.000000      0.000000      3.000000      0.000000
# max        3.000000      9.000000     24.000000     33.000000     27.000000
#
#              var_38        var_49        var_52        var_58        var_62  \
# count  24500.000000  24500.000000  24500.000000  24500.000000  24500.000000
# mean       0.113020     40.435633      0.045959      0.208286      2.726327
# std        0.571228     47.357524      0.209401      0.785344      1.136362
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.000000      0.000000      0.000000      3.000000
# 50%        0.000000      3.000000      0.000000      0.000000      3.000000
# 75%        0.000000     99.000000      0.000000      0.000000      3.000000
# max        3.000000     99.000000      1.000000     15.000000     33.000000
#
#        ...       var_255       var_261       var_266       var_271  \
# count  ...  24500.000000  24500.000000  24500.000000  24500.000000
# mean   ...     63.376736      1.629343     34.968528      0.179449
# std    ...    382.677763      7.488873    371.785970      0.966962
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...  12672.000000    226.590000  26289.421800     43.200000
#
#             var_272        var_276       var_277       var_279       var_288  \
# count  24500.000000   24500.000000  24500.000000  24500.000000  24500.000000
# mean       1.169796     760.923713      2.108832      2.799549      0.110804
# std        4.864488   12060.271412      8.616134     10.460820      1.083260
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.000000       0.000000      0.000000      0.000000      0.000000
# 50%        0.000000       0.000000      0.000000      0.000000      0.000000
# 75%        0.000000       0.000000      0.000000      0.000000      0.000000
# max      107.160000  787920.000000    247.950000    253.800000     41.850000
#
#            var_292
# count  24500.00000
# mean       0.09703
# std        1.26670
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max       74.52000
#
# [8 rows x 102 columns]

# %% [markdown]
# ### Variance Threshold

# %% [markdown]
# Po takiej selekcji, nasze cechy możemy dodatkowo ograniczyć ze względu na wariancję.
# Użyjemy do tego poniższej funkcji:

# %%
def rem_by_Var_threshold(df, threshold):
    X = df.drop('target', axis=1)
    
    selector = VarianceThreshold(threshold=threshold)
    selector.fit(X)
    selected_features = X.columns[selector.get_support()]
    X_selected = X[selected_features]
    return X_selected.join(df.target)

# %% [markdown]
# Patrząc na wariancje za pomocą powyższej funkcji możemy usunąć cechy, które mają ją za małą - niosą ze sobą bardzo mało informacji. Nie wykorzystujemy jednak tej funkcji w naszym zbiorze danych - zbadaliśmy że nie daje satysfakcjonujących wyników.

# %% [markdown]
# ## Podsumowanie preprocessingu

# %% [markdown]
# ### Co z kodowaniem zmiennych całkowitoliczbowych i skalowanie zmiennych?
#
# Oczywiście nie zapomnieliśmy o tych krokach, będziemy je natomiast uskuteczniać w zależności od dobranego modelu i umieścimy je w pipe'ach.

# %% [markdown]
# ### Co z outlierami?
#
# Traktując zmienne dyskretne jako kategoryczne i przyglądając się dziwnym i często dośc losowym rozkładom zmiennych ciągłych nie jesteśmy w stanie stwierdzić co jest tak naprawdę outlierem. Nie pomaga w tym również brak wiedzy eksperckiej z zakresu badanego problemu i brak wiedzy na temat znaczenia cech zbioru danych.

# %% [markdown]
# ### A inżynieria i dobór cech?
#
# Oprócz zawartej już w preprocessingu analizy korelacji, inżynierię i dobór cech przeprowadzimy dla każdego modelu oddzielnie.

# %% [markdown]
# ### Co udało się zrealizować
#
# Zapoznaliśmy się ze zbiorem danych. Do tej pory znajdowaliśmy kolumny składające się z jednej lub prawie jednej wartości, kolumny zduplikowane, skorelowane i nie niosące informacji o 1. Oczywiście niektóre z naszych podejść może okazać się błędne, więc opakowaliśmy procedury procesujące w funkcje, tak aby dobierać ich parametry w zależności od modelu.
#
# Cały opisany dotychczas preprocessing zawieramy w transformatorze ColumnRemover - dzięki utworzeniu osobnej klasy procesującej będziemy mogli używać go w pipe'ach i column transformerach i dobierać parametry za pomocą grid search.

# %%
class ColumnRemover(BaseEstimator, TransformerMixin):

    def __init__(self, threshold_constant, threshold_corr, n_info_vals):
        self.threshold_constant = threshold_constant
        self.threshold_corr = threshold_corr
        self.n_info_vals = n_info_vals
        self.columns_to_remove = []
        self.columns_to_keep = []

    def fit(self, X, y=None):
        # usuwanie zduplikowanych kolumn
        self.columns_to_remove.extend(X.loc[:, X.T.duplicated()].columns.tolist())

        # usuwanie stałych i prawie stałych kolumn
        for column in X.columns:
            if X[column].value_counts(normalize=True).iloc[0] >= self.threshold_constant:
                self.columns_to_remove.append(column)

        # usuwanie skorelowanych kolumn, jeśli pierwsza kolumna jest ciągła stosujemy korelację pearsona,
        # jeśli dyskretna to korelację spearmana; pierwsza kolumna będzie typu takiego samego jak cały X ponieważ
        # klasę tą stosujemy w column tranformerze ograniczając podzbiór kolumn do okreslonego typu
        if X.dtypes[0] == 'float64':
            corr = X.corr(method='pearson')
        else:
            corr = X.corr(method='spearman')
        corr = corr[corr > self.threshold_corr]
        dependent_columns = corr.apply(lambda row: row[row > 0].index, axis=1)
        for j in range (len(dependent_columns)):
            for k in dependent_columns[j]:
                if k is not dependent_columns.index[j]:
                    if k not in dependent_columns.index[0:j]:
                        self.columns_to_remove.append(k)

        # usuwanie kolumn nie niosących informacji
        amount_of_ones = y[y == 1].shape[0]
        X = X.join(y)
        for column in X.columns:
            tmp = X.groupby(column)['target'].agg(['sum','count']).sort_values('sum',ascending = False).reset_index()
            if any(tmp[column] == 0) and (tmp.loc[tmp[column] == 0, 'sum'] > amount_of_ones - self.n_info_vals).bool():
                self.columns_to_remove.append(column)
        X.drop('target', axis=1, inplace=True)

        self.columns_to_keep = [col for col in X.columns if col not in self.columns_to_remove]

        return self

    def transform(self, X):
        return X[self.columns_to_keep]

# %% [markdown]
# Utworzyliśmy ponadto funkcję liczącą wszystko za nas i wyświetlającą macierz pomyłek oraz interesujące nas metryki

# %%
def show_scores(clf, X, y):
    y_pred = clf.predict(X)
    y_pred_prob = clf.predict_proba(X)
    print(tabulate(confusion_matrix(y, y_pred), headers=['Predicted 0', 'Predicted 1'], tablefmt='orgtbl'))
    print()
    print(f'accuracy:              {round(accuracy_score(y, y_pred), 4)}')
    print(f'precision:             {round(precision_score(y, y_pred), 4)}')
    print(f'recall:                {round(recall_score(y, y_pred), 4)}')
    print(f'f1:                    {round(f1_score(y, y_pred), 4)}')
    print(f'roc_auc_discrete:      {round(roc_auc_score(y, y_pred), 4)}')
    print(f'roc_auc_continuous:    {round(roc_auc_score(y, y_pred_prob[:, 1]), 4)}')

# %% [markdown]
# Przejdźmy zatem do modeli

# %% [markdown]
# # 3. Regresja logistyczna

# %% [markdown]
# ## 3.1 Preprocessing

# %%
# zarówno dla zmiennych dyskretnych i ciągłych stosujemy nasz transformator ColumnRemover z różnymi parametrami - w kolejnych krokach będziemy szukać najlepszej ich kombinacji

# dokonujemy kodowania one hot encoding zmiennych dyskretnych - traktujemy je jako kategoryczne
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9995, 0.99, 1)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

# dokojumeny standaryzacji zmiennych ciągłych - sprawdziliśmy, że jest lepsza od normalizacji min-max dla tego modelu
float_transformer = Pipeline([
    ('float', ColumnRemover(0.9999, 0.99, 10)),
    ('standard_scaler', StandardScaler())])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

# %% [markdown]
# ## 3.2 Trening pierwszego modelu

# %%
X_train = train_df.drop('target', axis=1)
y_train = train_df.target
X_test = test_df.drop('target', axis=1)
y_test = test_df.target

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', LogisticRegression(random_state=42))])

clf.fit(X_train, y_train)

# wyniki dla danych treningowych
show_scores(clf, X_train, y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23550 |            10 |
# |           934 |             6 |
#
# accuracy:              0.9615
# precision:             0.375
# recall:                0.0064
# f1:                    0.0126
# roc_auc_discrete:      0.503
# roc_auc_continuous:    0.8057

# %%
# wyniki dla danych testowych
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         10033 |            17 |
# |           449 |             1 |
#
# accuracy:              0.9556
# precision:             0.0556
# recall:                0.0022
# f1:                    0.0043
# roc_auc_discrete:      0.5003
# roc_auc_continuous:    0.7813

# %% [markdown]
# Model się nie uczy. Wiemy, że klasy są niezbalansowane (jest ok. 4% jedynek). Zastosujemy parametr class_weight = 'balanced')

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16261 |          7299 |
# |           207 |           733 |
#
# accuracy:              0.6936
# precision:             0.0913
# recall:                0.7798
# f1:                    0.1634
# roc_auc_discrete:      0.735
# roc_auc_continuous:    0.8125

# %%
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6841 |          3209 |
# |           120 |           330 |
#
# accuracy:              0.683
# precision:             0.0932
# recall:                0.7333
# f1:                    0.1655
# roc_auc_discrete:      0.707
# roc_auc_continuous:    0.7784

# %% [markdown]
# Daje nam to minimalne podstawy do dalszego doboru parametrów.

# %% [markdown]
# ## 3.3 Strojenie hiperparametrów i dobór cech

# %% [markdown]
# ### 3.3.1 Dobór parametrów dla ColumnRemover'a

# %%
X_train = train_df.drop('target', axis=1)
y_train = train_df.target
X_test = test_df.drop('target', axis=1)
y_test = test_df.target

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))])

parameters = dict(preprocessing__int_pipe__int__threshold_constant = np.arange(0.9995, 1, 0.0001),
                  preprocessing__int_pipe__int__threshold_corr = np.arange(0.96, 1, 0.01),
                  preprocessing__int_pipe__int__n_info_vals = np.arange(0, 5, 1),
                  preprocessing__float_pipe__float__threshold_constant = np.arange(0.9995, 1, 0.0001),
                  preprocessing__float_pipe__float__threshold_corr = np.arange(0.96, 1, 0.01),
                  preprocessing__float_pipe__float__n_info_vals = np.arange(0, 16, 3))

col_remove_search = RandomizedSearchCV(clf, scoring='roc_auc', param_distributions=parameters, cv=3, n_iter=1000, n_jobs=-1, random_state=42).fit(X_train, y_train)

# %% [markdown]
# Sprawdzamy rezultaty treningu

# %%
print(round(col_remove_search.best_score_, 4), col_remove_search.best_params_)
# Out:
# 0.7845 {'preprocessing__int_pipe__int__threshold_corr': 1.0, 'preprocessing__int_pipe__int__threshold_constant': 0.9998, 'preprocessing__int_pipe__int__n_info_vals': 0, 'preprocessing__float_pipe__float__threshold_corr': 0.97, 'preprocessing__float_pipe__float__threshold_constant': 0.9996, 'preprocessing__float_pipe__float__n_info_vals': 0}

# %%
show_scores(col_remove_search.best_estimator_, X_train, y_train)
show_scores(col_remove_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16407 |          7153 |
# |           205 |           735 |
#
# accuracy:              0.6997
# precision:             0.0932
# recall:                0.7819
# f1:                    0.1665
# roc_auc_discrete:      0.7392
# roc_auc_continuous:    0.8155
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6898 |          3152 |
# |           121 |           329 |
#
# accuracy:              0.6883
# precision:             0.0945
# recall:                0.7311
# f1:                    0.1674
# roc_auc_discrete:      0.7087
# roc_auc_continuous:    0.776

# %% [markdown]
# Otrzymujemy porównywalne wyniki.

# %% [markdown]
# ### 3.3.2 Regularyzacja modelu
#
# Zajmiemy się regularyzacją modelu regresji liniowej - będziemy sprawdzać odwrotność współczynnika regularyzacji (im większy tym mniejsza regulacja), oraz rodzaj kary (l1 - regresja LASSO, l2 - regresja grzbietowa). Zastosujemy podadto parametry ColumnRemovera ustalone w poprzednich podpunktach.

# %%
# ustawiamy parametry ColumnRemovera na znalezione w 3.3.1
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9998, 1, 0)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

float_transformer = Pipeline([
    ('float', ColumnRemover(0.9996, 0.97, 0)),
    ('standard_scaler', StandardScaler())])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

X_train = col_transformer.fit_transform(train_df.drop('target', axis=1), train_df.target)
y_train = train_df.target
X_test = col_transformer.transform(test_df.drop('target', axis=1))
y_test = test_df.target

# %%
clf = LogisticRegression(random_state=42, class_weight='balanced', solver='liblinear')

parameters = dict(C=np.logspace(-6, 2, 20), penalty=['l1', 'l2'])
reg_search = GridSearchCV(clf, scoring='roc_auc', cv=3, return_train_score=True, param_grid=parameters, n_jobs=-1).fit(X_train, y_train)

# %% [markdown]
# Sprawdzamy najlepsze parametry i wyniki dla najlepszego modelu

# %%
print(round(reg_search.best_score_, 4), reg_search.best_params_)
# Out:
# 0.7879 {'C': 0.11288378916846883, 'penalty': 'l1'}

# %%
show_scores(reg_search.best_estimator_, X_train, y_train)
show_scores(reg_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16357 |          7203 |
# |           213 |           727 |
#
# accuracy:              0.6973
# precision:             0.0917
# recall:                0.7734
# f1:                    0.1639
# roc_auc_discrete:      0.7338
# roc_auc_continuous:    0.8121
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6894 |          3156 |
# |           121 |           329 |
#
# accuracy:              0.6879
# precision:             0.0944
# recall:                0.7311
# f1:                    0.1672
# roc_auc_discrete:      0.7085
# roc_auc_continuous:    0.782

# %%
cvres = reg_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(round(mean_score, 4), "   ", params)
# Out:
# 0.5     {'C': 1e-06, 'penalty': 'l1'}
# 0.7605     {'C': 1e-06, 'penalty': 'l2'}
# 0.5     {'C': 2.6366508987303555e-06, 'penalty': 'l1'}
# 0.761     {'C': 2.6366508987303555e-06, 'penalty': 'l2'}
# 0.5     {'C': 6.951927961775606e-06, 'penalty': 'l1'}
# 0.7628     {'C': 6.951927961775606e-06, 'penalty': 'l2'}
# 0.5     {'C': 1.8329807108324375e-05, 'penalty': 'l1'}
# 0.766     {'C': 1.8329807108324375e-05, 'penalty': 'l2'}
# 0.5     {'C': 4.8329302385717524e-05, 'penalty': 'l1'}
# 0.7709     {'C': 4.8329302385717524e-05, 'penalty': 'l2'}
# 0.5     {'C': 0.00012742749857031334, 'penalty': 'l1'}
# 0.7755     {'C': 0.00012742749857031334, 'penalty': 'l2'}
# 0.5     {'C': 0.0003359818286283781, 'penalty': 'l1'}
# 0.7801     {'C': 0.0003359818286283781, 'penalty': 'l2'}
# 0.7333     {'C': 0.0008858667904100823, 'penalty': 'l1'}
# 0.7832     {'C': 0.0008858667904100823, 'penalty': 'l2'}
# 0.7714     {'C': 0.002335721469090121, 'penalty': 'l1'}
# 0.7851     {'C': 0.002335721469090121, 'penalty': 'l2'}
# 0.7792     {'C': 0.00615848211066026, 'penalty': 'l1'}
# 0.786     {'C': 0.00615848211066026, 'penalty': 'l2'}
# 0.7861     {'C': 0.01623776739188721, 'penalty': 'l1'}
# 0.7866     {'C': 0.01623776739188721, 'penalty': 'l2'}
# 0.7873     {'C': 0.04281332398719396, 'penalty': 'l1'}
# 0.7866     {'C': 0.04281332398719396, 'penalty': 'l2'}
# 0.7879     {'C': 0.11288378916846883, 'penalty': 'l1'}
# 0.7855     {'C': 0.11288378916846883, 'penalty': 'l2'}
# 0.786     {'C': 0.2976351441631313, 'penalty': 'l1'}
# 0.7846     {'C': 0.2976351441631313, 'penalty': 'l2'}
# 0.7845     {'C': 0.7847599703514607, 'penalty': 'l1'}
# 0.7836     {'C': 0.7847599703514607, 'penalty': 'l2'}
# 0.7822     {'C': 2.06913808111479, 'penalty': 'l1'}
# 0.7822     {'C': 2.06913808111479, 'penalty': 'l2'}
# 0.7809     {'C': 5.455594781168514, 'penalty': 'l1'}
# 0.7812     {'C': 5.455594781168514, 'penalty': 'l2'}
# 0.78     {'C': 14.384498882876601, 'penalty': 'l1'}
# 0.7804     {'C': 14.384498882876601, 'penalty': 'l2'}
# 0.7797     {'C': 37.92690190732246, 'penalty': 'l1'}
# 0.7799     {'C': 37.92690190732246, 'penalty': 'l2'}
# 0.7798     {'C': 100.0, 'penalty': 'l1'}
# 0.7796     {'C': 100.0, 'penalty': 'l2'}

# %% [markdown]
# Skorzystamy z wyznaczonych najlepszych parametrów przy selekcji cech metodą lasso.

# %% [markdown]
# ### 3.3.3 Dobór zmiennych nie wymagajacy modelu
#
# Korelację uwzględniliśmy w transformatorze ColumnRemover. Technika którą wykorzystamy poniżej to Univariate feature selection - SelectKBest.

# %% [markdown]
# ### SelectKBest

# %%
# szukamy najlepszego parametru k w SelectKBest
clf = Pipeline([
    ('select', SelectKBest()),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))])

parameters = dict(select__k=np.arange(1, 200, 1))
k_best_search = GridSearchCV(clf, scoring='roc_auc', cv=3, return_train_score=True, param_grid=parameters, n_jobs=-1).fit(X_train, y_train)

# %%
# wyniki dla najlepszego znalezionego parametru
print(round(k_best_search.best_score_, 4), k_best_search.best_params_)
# Out:
# 0.7928 {'select__k': 154}

# %%
show_scores(k_best_search.best_estimator_, X_train, y_train)
show_scores(k_best_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16290 |          7270 |
# |           208 |           732 |
#
# accuracy:              0.6948
# precision:             0.0915
# recall:                0.7787
# f1:                    0.1637
# roc_auc_discrete:      0.7351
# roc_auc_continuous:    0.8102
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6884 |          3166 |
# |           121 |           329 |
#
# accuracy:              0.687
# precision:             0.0941
# recall:                0.7311
# f1:                    0.1668
# roc_auc_discrete:      0.708
# roc_auc_continuous:    0.7796

# %% [markdown]
# Wydaje się dość duże k, zobaczmy, jak prezentują się wszystkie wyniki

# %%
cvres = k_best_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(round(mean_score, 4), "   ", params)
# Out:
# 0.6717     {'select__k': 1}
# 0.6741     {'select__k': 2}
# 0.6741     {'select__k': 3}
# 0.675     {'select__k': 4}
# 0.6772     {'select__k': 5}
# 0.6819     {'select__k': 6}
# 0.6822     {'select__k': 7}
# 0.6914     {'select__k': 8}
# 0.7001     {'select__k': 9}
# 0.7115     {'select__k': 10}
# 0.7108     {'select__k': 11}
# 0.7657     {'select__k': 12}
# 0.7659     {'select__k': 13}
# 0.7651     {'select__k': 14}
# 0.7779     {'select__k': 15}
# 0.7781     {'select__k': 16}
# 0.778     {'select__k': 17}
# 0.7785     {'select__k': 18}
# 0.7786     {'select__k': 19}
# 0.7785     {'select__k': 20}
# 0.78     {'select__k': 21}
# 0.7802     {'select__k': 22}
# 0.7804     {'select__k': 23}
# 0.7805     {'select__k': 24}
# 0.7806     {'select__k': 25}
# 0.7806     {'select__k': 26}
# 0.7811     {'select__k': 27}
# 0.7815     {'select__k': 28}
# 0.7816     {'select__k': 29}
# 0.7817     {'select__k': 30}
# 0.7819     {'select__k': 31}
# 0.7843     {'select__k': 32}
# 0.7844     {'select__k': 33}
# 0.7843     {'select__k': 34}
# 0.7843     {'select__k': 35}
# 0.7838     {'select__k': 36}
# 0.7838     {'select__k': 37}
# 0.7838     {'select__k': 38}
# 0.7839     {'select__k': 39}
# 0.7838     {'select__k': 40}
# 0.7834     {'select__k': 41}
# 0.7838     {'select__k': 42}
# 0.7836     {'select__k': 43}
# 0.7837     {'select__k': 44}
# 0.7837     {'select__k': 45}
# 0.7847     {'select__k': 46}
# 0.7844     {'select__k': 47}
# 0.7844     {'select__k': 48}
# 0.7844     {'select__k': 49}
# 0.7845     {'select__k': 50}
# 0.7847     {'select__k': 51}
# 0.7858     {'select__k': 52}
# 0.7858     {'select__k': 53}
# 0.7856     {'select__k': 54}
# 0.7859     {'select__k': 55}
# 0.7854     {'select__k': 56}
# 0.7855     {'select__k': 57}
# 0.7855     {'select__k': 58}
# 0.7853     {'select__k': 59}
# 0.7853     {'select__k': 60}
# 0.7852     {'select__k': 61}
# 0.7853     {'select__k': 62}
# 0.7851     {'select__k': 63}
# 0.7852     {'select__k': 64}
# 0.7854     {'select__k': 65}
# 0.7852     {'select__k': 66}
# 0.7846     {'select__k': 67}
# 0.7843     {'select__k': 68}
# 0.7844     {'select__k': 69}
# 0.7845     {'select__k': 70}
# 0.7861     {'select__k': 71}
# 0.7861     {'select__k': 72}
# 0.7861     {'select__k': 73}
# 0.7871     {'select__k': 74}
# 0.7869     {'select__k': 75}
# 0.7874     {'select__k': 76}
# 0.7872     {'select__k': 77}
# 0.7869     {'select__k': 78}
# 0.7872     {'select__k': 79}
# 0.7874     {'select__k': 80}
# 0.7872     {'select__k': 81}
# 0.7872     {'select__k': 82}
# 0.7874     {'select__k': 83}
# 0.7869     {'select__k': 84}
# 0.7874     {'select__k': 85}
# 0.7874     {'select__k': 86}
# 0.7881     {'select__k': 87}
# 0.7877     {'select__k': 88}
# 0.7879     {'select__k': 89}
# 0.7876     {'select__k': 90}
# 0.7879     {'select__k': 91}
# 0.7878     {'select__k': 92}
# 0.7881     {'select__k': 93}
# 0.7879     {'select__k': 94}
# 0.7881     {'select__k': 95}
# 0.788     {'select__k': 96}
# 0.788     {'select__k': 97}
# 0.7881     {'select__k': 98}
# 0.7878     {'select__k': 99}
# 0.786     {'select__k': 100}
# 0.7864     {'select__k': 101}
# 0.7866     {'select__k': 102}
# 0.7869     {'select__k': 103}
# 0.7868     {'select__k': 104}
# 0.787     {'select__k': 105}
# 0.7871     {'select__k': 106}
# 0.7873     {'select__k': 107}
# 0.7869     {'select__k': 108}
# 0.7876     {'select__k': 109}
# 0.7884     {'select__k': 110}
# 0.789     {'select__k': 111}
# 0.7895     {'select__k': 112}
# 0.789     {'select__k': 113}
# 0.7889     {'select__k': 114}
# 0.7892     {'select__k': 115}
# 0.7891     {'select__k': 116}
# 0.789     {'select__k': 117}
# 0.7892     {'select__k': 118}
# 0.7888     {'select__k': 119}
# 0.7891     {'select__k': 120}
# 0.7895     {'select__k': 121}
# 0.7891     {'select__k': 122}
# 0.7888     {'select__k': 123}
# 0.7882     {'select__k': 124}
# 0.7879     {'select__k': 125}
# 0.7874     {'select__k': 126}
# 0.7876     {'select__k': 127}
# 0.7887     {'select__k': 128}
# 0.7889     {'select__k': 129}
# 0.7896     {'select__k': 130}
# 0.7903     {'select__k': 131}
# 0.7909     {'select__k': 132}
# 0.7903     {'select__k': 133}
# 0.7905     {'select__k': 134}
# 0.7907     {'select__k': 135}
# 0.7913     {'select__k': 136}
# 0.7907     {'select__k': 137}
# 0.7912     {'select__k': 138}
# 0.7912     {'select__k': 139}
# 0.7912     {'select__k': 140}
# 0.7912     {'select__k': 141}
# 0.7909     {'select__k': 142}
# 0.7914     {'select__k': 143}
# 0.7923     {'select__k': 144}
# 0.7924     {'select__k': 145}
# 0.7922     {'select__k': 146}
# 0.7925     {'select__k': 147}
# 0.7921     {'select__k': 148}
# 0.7921     {'select__k': 149}
# 0.7919     {'select__k': 150}
# 0.7922     {'select__k': 151}
# 0.7924     {'select__k': 152}
# 0.7923     {'select__k': 153}
# 0.7928     {'select__k': 154}
# 0.7924     {'select__k': 155}
# 0.7913     {'select__k': 156}
# 0.7914     {'select__k': 157}
# 0.792     {'select__k': 158}
# 0.7911     {'select__k': 159}
# 0.7913     {'select__k': 160}
# 0.7907     {'select__k': 161}
# 0.7906     {'select__k': 162}
# 0.791     {'select__k': 163}
# 0.7903     {'select__k': 164}
# 0.7902     {'select__k': 165}
# 0.7901     {'select__k': 166}
# 0.7897     {'select__k': 167}
# 0.7907     {'select__k': 168}
# 0.79     {'select__k': 169}
# 0.7901     {'select__k': 170}
# 0.7901     {'select__k': 171}
# 0.7897     {'select__k': 172}
# 0.7901     {'select__k': 173}
# 0.7899     {'select__k': 174}
# 0.7893     {'select__k': 175}
# 0.7894     {'select__k': 176}
# 0.79     {'select__k': 177}
# 0.7898     {'select__k': 178}
# 0.7893     {'select__k': 179}
# 0.7895     {'select__k': 180}
# 0.79     {'select__k': 181}
# 0.7903     {'select__k': 182}
# 0.79     {'select__k': 183}
# 0.7896     {'select__k': 184}
# 0.7898     {'select__k': 185}
# 0.7893     {'select__k': 186}
# 0.7898     {'select__k': 187}
# 0.7899     {'select__k': 188}
# 0.7918     {'select__k': 189}
# 0.7916     {'select__k': 190}
# 0.7916     {'select__k': 191}
# 0.7909     {'select__k': 192}
# 0.7909     {'select__k': 193}
# 0.7912     {'select__k': 194}
# 0.791     {'select__k': 195}
# 0.7916     {'select__k': 196}
# 0.7914     {'select__k': 197}
# 0.791     {'select__k': 198}
# 0.7913     {'select__k': 199}

# %% [markdown]
# Wnioski: roc_auc maleje nieznacznie i wybierając dużo mniej zmiennych nie stracimy zbytnio na wyniku, a zmniejszymy drastycznie liczbę cech.

# %%
clf = Pipeline([
    ('select', SelectKBest(k=33)),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         15821 |          7739 |
# |           231 |           709 |
#
# accuracy:              0.6747
# precision:             0.0839
# recall:                0.7543
# f1:                    0.151
# roc_auc_discrete:      0.7129
# roc_auc_continuous:    0.7852
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6671 |          3379 |
# |           125 |           325 |
#
# accuracy:              0.6663
# precision:             0.0877
# recall:                0.7222
# f1:                    0.1565
# roc_auc_discrete:      0.693
# roc_auc_continuous:    0.7766

# %% [markdown]
# Obserwujemy nieznaczne pogorszenie wyników (szczególnie nieznaczne jest na zbiorze testowym), jednak zredukowaliśmy liczbę cech do zaledwie 33.

# %% [markdown]
# ### 3.3.4 Dobór zmiennych na podstawie modelu
#
# Dotychczasowe starania miały na celu osiągnięcie jak najlepszych rezultatów dla modelu. Teraz przeprowadzimy dobór cech na podstawie modelu ze znalezionymi najlepszymi parametrami. Zastosujemy metody L1-based feature selection, Sequential Feature Selection i RFE

# %% [markdown]
# ### SelectFromModel - L1-based feature selection

# %%
clf = LogisticRegression(**reg_search.best_params_, random_state=42, solver='liblinear', class_weight='balanced')
clf.fit(X_train, y_train)

show_scores(clf, X_train, y_train)
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16357 |          7203 |
# |           213 |           727 |
#
# accuracy:              0.6973
# precision:             0.0917
# recall:                0.7734
# f1:                    0.1639
# roc_auc_discrete:      0.7338
# roc_auc_continuous:    0.8121
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6894 |          3156 |
# |           121 |           329 |
#
# accuracy:              0.6879
# precision:             0.0944
# recall:                0.7311
# f1:                    0.1672
# roc_auc_discrete:      0.7085
# roc_auc_continuous:    0.782

# %%
X_train.shape[1]
# Out:
# 406

# %%
sfl = SelectFromModel(clf, prefit=True)
X_train_t = sfl.transform(X_train)
X_test_t = sfl.transform(X_test)
X_train_t.shape[1]
# Out:
# 114

# %%
clf.fit(X_train_t, y_train)

show_scores(clf, X_train_t, y_train)
show_scores(clf, X_test_t, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16357 |          7203 |
# |           213 |           727 |
#
# accuracy:              0.6973
# precision:             0.0917
# recall:                0.7734
# f1:                    0.1639
# roc_auc_discrete:      0.7338
# roc_auc_continuous:    0.8121
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          6894 |          3156 |
# |           121 |           329 |
#
# accuracy:              0.6879
# precision:             0.0944
# recall:                0.7311
# f1:                    0.1672
# roc_auc_discrete:      0.7085
# roc_auc_continuous:    0.7823

# %% [markdown]
# Nie obserwujemy żadnego spadku w wynikach - zreudkowaliśmy natomiast liczbę cech do 114.

# %% [markdown]
# ### Sequential Feature Selection

# %%
sfs = SequentialFeatureSelector(
    LogisticRegression(random_state=42, class_weight='balanced'),
    direction='forward',
    scoring='roc_auc',
    n_features_to_select=40,
    cv=3,
    n_jobs=-1)

pipe = Pipeline([
    ('selector', sfs),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))]).fit(X_train, y_train)

show_scores(pipe, X_train, y_train)

# %%
show_scores(pipe, X_test, y_test)

# %% [markdown]
# Po kilku próbach otrzymaliśmy niepogorszone wyniki dla zalwdwie 40 zmiennych na podstawie selekcji SequentialFeaturSelector. Nie szukamy w tym przypadku parametru n_features_to_select za pomocą grid search, ponieważ zajęło by nam to z pół roku, a zajęliśmy się empiryczym sprawdzeniem najlepszej wartości.

# %% [markdown]
# ### Recursive Feature Elimination

# %% [markdown]
# Dla najlepszego modelu regresji logistycznej sprawdźmy które cechy niosą za sobą najwięcej informacji

# %%
k_val = [k for k in range (2,100,2)]
score = []
for k in k_val:
    print(k)
    log_reg = LogisticRegression(random_state=42, class_weight='balanced', solver='liblinear')
    rfe = RFE(log_reg,n_features_to_select = k)
    rfe.fit(X_train, y_train)
    X_train_rfe = rfe.transform(X_train)
    X_test_rfe = rfe.transform(X_test)
    log_reg.fit(X_train_rfe, y_train)

    y_pred_prob = log_reg.predict_proba(pd.DataFrame(X_test_rfe))

    score_roc = roc_auc_score(y_test, y_pred_prob[:, 1])
    score.append(score_roc)
    print(score_roc, k)

# %%
plt.stem(score)
plt.xticks(k_val, score)
plt.xlim([-1, 50])
plt.xlabel("K Values")
plt.ylabel("roc_auc Score")

# %% [markdown]
# ![fre_logreg.png](./Img/rfe_logreg.png)
#
# Z powyższego wykresu możemy wyczytać, że najlepiej będzie użyć rfe dla 72 cech.
# W związku z tym spróbujmy użyć PCA na wybranych kolumnach.
#
# (uwaga: ten i pozostałe wykresy zawarte w tym notatniku zostały przeklejone z innych naszych notatników ze względu na długi czas liczenia kodu rfe)

# %% [markdown]
# ### Principal Component Analysis

# %%
rfe = RFE(LogisticRegression(random_state=42, class_weight='balanced', solver='liblinear'),n_features_to_select = 72).fit(X_train, y_train)
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

k_values = [i for i in range (2,72)]
scores = []

for k in k_values:

    log_reg = LogisticRegression(random_state=42, class_weight='balanced', solver='liblinear')
    pca = PCA(n_components=k)

    X_red_train = pca.fit_transform(X_train_rfe)
    X_red_test = pca.fit_transform(X_test_rfe)

    log_reg.fit(X_red_train, y_train)
    y_pred_prob = log_reg.predict_proba(pd.DataFrame(X_red_test))

    score_roc = roc_auc_score(y_test, y_pred_prob[:, 1])
    scores.append(score_roc)

# %%
plt.stem(scores)
plt.xticks(k_values, scores)
plt.xlim([-1, 72])
plt.xlabel("K Values")
plt.ylabel("roc_auc Score")
plt.title("PCA for linear regression")

# %% [markdown]
# ![linear_reg.png](./Img/linear_reg.png)

# %% [markdown]
# Widzimy więc, że dla tego modelu najlepiej będzie wybrać wartość n_components = 3

# %% [markdown]
# ### 3.4 Podsumowanie
#
# Model regresji logistycznej działa przyzwoicie jak na warunki otrzymanego zbioru danych. Istotne wydaje się użycie parametry class_weight = 'balanced'. Przeprowadziliśmy przeszukanie siatki parametrów autorskiego ColumnRemover'a, a następnie przeszukiwanie siatki parametru C i kar w celu dobrania najlepszych parametrów regularyzacji.
#
# Następnie przeszliśmy do selekcji cech różnymi metodami. W wielu przypadkach zaobserwowaliśmy znaczny spadek liczby kolumn przy jednoczesnym braku znaczącego pogorszenia rezultatów (nie zaobserwowaliśmy znaczącego wzrostu rezultatów przy jakiejkolwiek redukcji cech). Metody jakie wybraliśmy i ostateczna liczba zmiennych prezentują się następujaco:
#
# - SelectKBest - 33
# - L1-based feature selection - 114
# - Sequential feature selection - 40
# - Recursive feature elimination - 72
# - RFE + PCA - 3

# %% [markdown]
# # 4. Drzewa decyzyjne

# %% [markdown]
# ## 4.1 Preprocessing

# %%
# zarówno dla zmiennych dyskretnych i ciągłych stosujemy nasz transformator ColumnRemover z różnymi parametrami - w kolejnych krokach będziemy szukać najlepszej ich kombinacji

# dokonujemy kodowania one hot encoding zmiennych dyskretnych - traktujemy je jako kategoryczne
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9995, 0.99, 1)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

# jesteśmy przy drzewach decyzyjnych, więc nie musimy skalować cech
float_transformer = Pipeline([
    ('float', ColumnRemover(0.9999, 0.99, 10))])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

# %% [markdown]
# ## 4.2 Trening pierwszego modelu

# %%
X_train = train_df.drop('target', axis=1)
y_train = train_df.target
X_test = test_df.drop('target', axis=1)
y_test = test_df.target

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', DecisionTreeClassifier(random_state=42))])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |             3 |           937 |
#
# accuracy:              0.9999
# precision:             1.0
# recall:                0.9968
# f1:                    0.9984
# roc_auc_discrete:      0.9984
# roc_auc_continuous:    1.0

# %%
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9654 |           396 |
# |           384 |            66 |
#
# accuracy:              0.9257
# precision:             0.1429
# recall:                0.1467
# f1:                    0.1447
# roc_auc_discrete:      0.5536
# roc_auc_continuous:    0.5536

# %% [markdown]
# Model jest zdecydowanie przeuczony. Spróbujmy z parametrem class_weight='balanced'.

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', DecisionTreeClassifier(random_state=42, class_weight='balanced'))])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23557 |             3 |
# |             0 |           940 |
#
# accuracy:              0.9999
# precision:             0.9968
# recall:                1.0
# f1:                    0.9984
# roc_auc_discrete:      0.9999
# roc_auc_continuous:    1.0

# %%
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9705 |           345 |
# |           399 |            51 |
#
# accuracy:              0.9291
# precision:             0.1288
# recall:                0.1133
# f1:                    0.1206
# roc_auc_discrete:      0.5395
# roc_auc_continuous:    0.5395

# %% [markdown]
# Za dużo to nie dało, musimy skupić się na regularyzacji modelu drzewa decyzyjnego.

# %% [markdown]
# ## 4.3 Strojenie hiperparametrów i wybór zmiennych

# %% [markdown]
# ### 4.3.1 Dobór parametrów dla ColumnRemover'a

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', DecisionTreeClassifier(random_state=42))])

parameters = dict(preprocessing__int_pipe__int__threshold_constant = np.arange(0.9995, 1, 0.0001),
                  preprocessing__int_pipe__int__threshold_corr = np.arange(0.96, 1, 0.01),
                  preprocessing__int_pipe__int__n_info_vals = np.arange(0, 5, 1),
                  preprocessing__float_pipe__float__threshold_constant = np.arange(0.9995, 1, 0.0001),
                  preprocessing__float_pipe__float__threshold_corr = np.arange(0.96, 1, 0.01),
                  preprocessing__float_pipe__float__n_info_vals = np.arange(0, 16, 3))

# siatka parametrów ma liczność 27000, przeszukujemy więc ok. 37% wszystkich możliwości
col_remove_search = RandomizedSearchCV(clf, scoring='roc_auc', param_distributions=parameters, cv=3, n_iter=10000, n_jobs=-1, random_state=42).fit(X_train, y_train)

# %%
print(round(col_remove_search.best_score_, 4), col_remove_search.best_params_)
# Out:
# 0.5594 {'preprocessing__int_pipe__int__threshold_corr': 0.99, 'preprocessing__int_pipe__int__threshold_constant': 0.9998, 'preprocessing__int_pipe__int__n_info_vals': 2, 'preprocessing__float_pipe__float__threshold_corr': 0.96, 'preprocessing__float_pipe__float__threshold_constant': 0.9998, 'preprocessing__float_pipe__float__n_info_vals': 15}

# %%
show_scores(col_remove_search.best_estimator_, X_train, y_train)
show_scores(col_remove_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |             3 |           937 |
#
# accuracy:              0.9999
# precision:             1.0
# recall:                0.9968
# f1:                    0.9984
# roc_auc_discrete:      0.9984
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9653 |           397 |
# |           379 |            71 |
#
# accuracy:              0.9261
# precision:             0.1517
# recall:                0.1578
# f1:                    0.1547
# roc_auc_discrete:      0.5591
# roc_auc_continuous:    0.5591

# %% [markdown]
# ### 4.3.2 Regularyzacja modelu
#
# Zajmiemy się regularyzacją modelu drzewa decyzyjnego - będziemy sprawdzać parametry max_depth, min_samples_split, min_samples_leaf, max_features. Na początek jednak skupimy się tylko na max_depth - być może z jego powodu drzewo jest tak mocno przeuczone. Zastosujemy również najlepsze parametry ColumnRemovera znalezione w poprzednim podpunkcie

# %%
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9998, 0.99, 2)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

float_transformer = Pipeline([
    ('float', ColumnRemover(0.9998, 0.96, 15))])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

# od tej pory dane testowe i treningowe będą już wstępnie przeprocesowane
X_train = col_transformer.fit_transform(train_df.drop('target', axis=1), train_df.target)
y_train = train_df.target
X_test = col_transformer.transform(test_df.drop('target', axis=1))
y_test = test_df.target

# %%
clf = DecisionTreeClassifier(random_state=42)

parameters = dict(max_depth=np.arange(1, 100))
depth_search = GridSearchCV(clf, cv=3, scoring='roc_auc', return_train_score=True, param_grid=parameters, n_jobs=-1).fit(X_train, y_train)

# %%
print(round(depth_search.best_score_, 4), depth_search.best_params_)
# Out:
# 0.8008 {'max_depth': 4}

# %%
cvres = depth_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(round(mean_score, 4), "   ", params)
# Out:
# 0.6825     {'max_depth': 1}
# 0.7438     {'max_depth': 2}
# 0.7854     {'max_depth': 3}
# 0.8008     {'max_depth': 4}
# 0.8004     {'max_depth': 5}
# 0.7919     {'max_depth': 6}
# 0.784     {'max_depth': 7}
# 0.7719     {'max_depth': 8}
# 0.7647     {'max_depth': 9}
# 0.7471     {'max_depth': 10}
# 0.7353     {'max_depth': 11}
# 0.7092     {'max_depth': 12}
# 0.7082     {'max_depth': 13}
# 0.6954     {'max_depth': 14}
# 0.669     {'max_depth': 15}
# 0.6699     {'max_depth': 16}
# 0.6698     {'max_depth': 17}
# 0.6551     {'max_depth': 18}
# 0.6485     {'max_depth': 19}
# 0.6425     {'max_depth': 20}
# 0.6273     {'max_depth': 21}
# 0.6207     {'max_depth': 22}
# 0.6081     {'max_depth': 23}
# 0.5975     {'max_depth': 24}
# 0.5985     {'max_depth': 25}
# 0.5914     {'max_depth': 26}
# 0.581     {'max_depth': 27}
# 0.5752     {'max_depth': 28}
# 0.5757     {'max_depth': 29}
# 0.5654     {'max_depth': 30}
# 0.5616     {'max_depth': 31}
# 0.5602     {'max_depth': 32}
# 0.5574     {'max_depth': 33}
# 0.5581     {'max_depth': 34}
# 0.5567     {'max_depth': 35}
# 0.5569     {'max_depth': 36}
# 0.5569     {'max_depth': 37}
# 0.557     {'max_depth': 38}
# 0.555     {'max_depth': 39}
# 0.5531     {'max_depth': 40}
# 0.5531     {'max_depth': 41}
# 0.5531     {'max_depth': 42}
# 0.5531     {'max_depth': 43}
# 0.5531     {'max_depth': 44}
# 0.5531     {'max_depth': 45}
# 0.5531     {'max_depth': 46}
# 0.5531     {'max_depth': 47}
# 0.5531     {'max_depth': 48}
# 0.5531     {'max_depth': 49}
# 0.5531     {'max_depth': 50}
# 0.5531     {'max_depth': 51}
# 0.5531     {'max_depth': 52}
# 0.5531     {'max_depth': 53}
# 0.5531     {'max_depth': 54}
# 0.5531     {'max_depth': 55}
# 0.5531     {'max_depth': 56}
# 0.5531     {'max_depth': 57}
# 0.5531     {'max_depth': 58}
# 0.5531     {'max_depth': 59}
# 0.5531     {'max_depth': 60}
# 0.5531     {'max_depth': 61}
# 0.5531     {'max_depth': 62}
# 0.5531     {'max_depth': 63}
# 0.5531     {'max_depth': 64}
# 0.5531     {'max_depth': 65}
# 0.5531     {'max_depth': 66}
# 0.5531     {'max_depth': 67}
# 0.5531     {'max_depth': 68}
# 0.5531     {'max_depth': 69}
# 0.5531     {'max_depth': 70}
# 0.5531     {'max_depth': 71}
# 0.5531     {'max_depth': 72}
# 0.5531     {'max_depth': 73}
# 0.5531     {'max_depth': 74}
# 0.5531     {'max_depth': 75}
# 0.5531     {'max_depth': 76}
# 0.5531     {'max_depth': 77}
# 0.5531     {'max_depth': 78}
# 0.5531     {'max_depth': 79}
# 0.5531     {'max_depth': 80}
# 0.5531     {'max_depth': 81}
# 0.5531     {'max_depth': 82}
# 0.5531     {'max_depth': 83}
# 0.5531     {'max_depth': 84}
# 0.5531     {'max_depth': 85}
# 0.5531     {'max_depth': 86}
# 0.5531     {'max_depth': 87}
# 0.5531     {'max_depth': 88}
# 0.5531     {'max_depth': 89}
# 0.5531     {'max_depth': 90}
# 0.5531     {'max_depth': 91}
# 0.5531     {'max_depth': 92}
# 0.5531     {'max_depth': 93}
# 0.5531     {'max_depth': 94}
# 0.5531     {'max_depth': 95}
# 0.5531     {'max_depth': 96}
# 0.5531     {'max_depth': 97}
# 0.5531     {'max_depth': 98}
# 0.5531     {'max_depth': 99}

# %%
show_scores(depth_search.best_estimator_, X_train, y_train)
show_scores(depth_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23557 |             3 |
# |           925 |            15 |
#
# accuracy:              0.9621
# precision:             0.8333
# recall:                0.016
# f1:                    0.0313
# roc_auc_discrete:      0.5079
# roc_auc_continuous:    0.8135
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         10040 |            10 |
# |           450 |             0 |
#
# accuracy:              0.9562
# precision:             0.0
# recall:                0.0
# f1:                    0.0
# roc_auc_discrete:      0.4995
# roc_auc_continuous:    0.7994

# %% [markdown]
# Dość podejrzane te wyniki. Spróbujmy znaleźć parametry z metryką f1

# %%
clf = DecisionTreeClassifier(random_state=42)

parameters = dict(max_depth=np.arange(1, 100))
depth_search = GridSearchCV(clf, cv=3, scoring='f1', return_train_score=True, param_grid=parameters, n_jobs=-1).fit(X_train, y_train)

# %%
print(round(depth_search.best_score_, 4), depth_search.best_params_)
# Out:
# 0.1421 {'max_depth': 29}

# %%
cvres = depth_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(round(mean_score, 4), "   ", params)
# Out:
# 0.0     {'max_depth': 1}
# 0.0     {'max_depth': 2}
# 0.0042     {'max_depth': 3}
# 0.0082     {'max_depth': 4}
# 0.0162     {'max_depth': 5}
# 0.0219     {'max_depth': 6}
# 0.0288     {'max_depth': 7}
# 0.0409     {'max_depth': 8}
# 0.047     {'max_depth': 9}
# 0.049     {'max_depth': 10}
# 0.0675     {'max_depth': 11}
# 0.076     {'max_depth': 12}
# 0.0827     {'max_depth': 13}
# 0.0854     {'max_depth': 14}
# 0.089     {'max_depth': 15}
# 0.0801     {'max_depth': 16}
# 0.086     {'max_depth': 17}
# 0.0932     {'max_depth': 18}
# 0.106     {'max_depth': 19}
# 0.1114     {'max_depth': 20}
# 0.1125     {'max_depth': 21}
# 0.122     {'max_depth': 22}
# 0.1213     {'max_depth': 23}
# 0.112     {'max_depth': 24}
# 0.1327     {'max_depth': 25}
# 0.1356     {'max_depth': 26}
# 0.129     {'max_depth': 27}
# 0.1317     {'max_depth': 28}
# 0.1421     {'max_depth': 29}
# 0.1343     {'max_depth': 30}
# 0.1357     {'max_depth': 31}
# 0.1409     {'max_depth': 32}
# 0.1354     {'max_depth': 33}
# 0.1382     {'max_depth': 34}
# 0.1385     {'max_depth': 35}
# 0.1383     {'max_depth': 36}
# 0.1379     {'max_depth': 37}
# 0.1396     {'max_depth': 38}
# 0.1379     {'max_depth': 39}
# 0.1357     {'max_depth': 40}
# 0.1357     {'max_depth': 41}
# 0.1357     {'max_depth': 42}
# 0.1357     {'max_depth': 43}
# 0.1357     {'max_depth': 44}
# 0.1357     {'max_depth': 45}
# 0.1357     {'max_depth': 46}
# 0.1357     {'max_depth': 47}
# 0.1357     {'max_depth': 48}
# 0.1357     {'max_depth': 49}
# 0.1357     {'max_depth': 50}
# 0.1357     {'max_depth': 51}
# 0.1357     {'max_depth': 52}
# 0.1357     {'max_depth': 53}
# 0.1357     {'max_depth': 54}
# 0.1357     {'max_depth': 55}
# 0.1357     {'max_depth': 56}
# 0.1357     {'max_depth': 57}
# 0.1357     {'max_depth': 58}
# 0.1357     {'max_depth': 59}
# 0.1357     {'max_depth': 60}
# 0.1357     {'max_depth': 61}
# 0.1357     {'max_depth': 62}
# 0.1357     {'max_depth': 63}
# 0.1357     {'max_depth': 64}
# 0.1357     {'max_depth': 65}
# 0.1357     {'max_depth': 66}
# 0.1357     {'max_depth': 67}
# 0.1357     {'max_depth': 68}
# 0.1357     {'max_depth': 69}
# 0.1357     {'max_depth': 70}
# 0.1357     {'max_depth': 71}
# 0.1357     {'max_depth': 72}
# 0.1357     {'max_depth': 73}
# 0.1357     {'max_depth': 74}
# 0.1357     {'max_depth': 75}
# 0.1357     {'max_depth': 76}
# 0.1357     {'max_depth': 77}
# 0.1357     {'max_depth': 78}
# 0.1357     {'max_depth': 79}
# 0.1357     {'max_depth': 80}
# 0.1357     {'max_depth': 81}
# 0.1357     {'max_depth': 82}
# 0.1357     {'max_depth': 83}
# 0.1357     {'max_depth': 84}
# 0.1357     {'max_depth': 85}
# 0.1357     {'max_depth': 86}
# 0.1357     {'max_depth': 87}
# 0.1357     {'max_depth': 88}
# 0.1357     {'max_depth': 89}
# 0.1357     {'max_depth': 90}
# 0.1357     {'max_depth': 91}
# 0.1357     {'max_depth': 92}
# 0.1357     {'max_depth': 93}
# 0.1357     {'max_depth': 94}
# 0.1357     {'max_depth': 95}
# 0.1357     {'max_depth': 96}
# 0.1357     {'max_depth': 97}
# 0.1357     {'max_depth': 98}
# 0.1357     {'max_depth': 99}

# %%
show_scores(depth_search.best_estimator_, X_train, y_train)
show_scores(depth_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23546 |            14 |
# |            29 |           911 |
#
# accuracy:              0.9982
# precision:             0.9849
# recall:                0.9691
# f1:                    0.9769
# roc_auc_discrete:      0.9843
# roc_auc_continuous:    0.9999
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9641 |           409 |
# |           378 |            72 |
#
# accuracy:              0.925
# precision:             0.1497
# recall:                0.16
# f1:                    0.1547
# roc_auc_discrete:      0.5597
# roc_auc_continuous:    0.5665

# %% [markdown]
# Wyniki wyglądają sensowniej niż dla roc_auc, co nie zmienia faktu, że drzewo nadal jest przeuczone i nie dostaliśmy lepszych wyników od braku regulacji. Spróbujemy określić pewną podprzestrzeń parametrów max_depth, min_samples_split, min_samples_leaf, max_features i wykorzystamy klasę RandomizedSearchCV do znalezienia optymalnej kombinacji. Wybierzemy metrykę f1, bo zauważyliśmy już, że dzięki roc_auc algorytm nie wyłapuje żadnych 1.

# %%
clf = DecisionTreeClassifier(random_state=42)

parameters = dict(max_depth=np.arange(25, 65, 3), min_samples_split=np.arange(2,8),
                  min_samples_leaf=np.arange(1, 20, 2), max_features=np.arange(20, 150, 5))

# siatka parametrów ma liczność 21840, przeszukujemy więc ok. 45,7% wszystkich możliwości
rand_search = RandomizedSearchCV(clf, scoring='f1', cv=3, return_train_score=True, param_distributions=parameters, n_iter=10000, n_jobs=-1, random_state=42).fit(X_train, y_train)

# %% [markdown]
# Sprawdzamy najlepszą kombinację

# %%
print(round(rand_search.best_score_, 4), rand_search.best_params_)
# Out:
# 0.1182 {'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 125, 'max_depth': 25}

# %%
show_scores(rand_search.best_estimator_, X_train, y_train)
show_scores(rand_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23394 |           166 |
# |           439 |           501 |
#
# accuracy:              0.9753
# precision:             0.7511
# recall:                0.533
# f1:                    0.6235
# roc_auc_discrete:      0.763
# roc_auc_continuous:    0.9878
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9778 |           272 |
# |           400 |            50 |
#
# accuracy:              0.936
# precision:             0.1553
# recall:                0.1111
# f1:                    0.1295
# roc_auc_discrete:      0.542
# roc_auc_continuous:    0.5879

# %% [markdown]
# Jak na kilka godzin szukania wyniki nie są powalające. Ciężko powiedzieć, czy regularyzacja coś daje w tym przypadku. Ale może chociaż inżynieria cech nam wyjdzie.

# %% [markdown]
# ### 4.3.3 Dobór zmiennych nie wymagajacy modelu
#
# Korelację uwzględniliśmy w transformatorze ColumnRemover. Technika którą wykorzystamy poniżej to Univariate feature selection - SelectKBest.

# %% [markdown]
# ### SelectKBest

# %%
# szukamy najlepszego parametru k w SelectKBest
clf = Pipeline([
    ('select', SelectKBest()),
    ('model', DecisionTreeClassifier(random_state=42))])

parameters = dict(select__k=np.arange(1, 200, 1))
k_best_search = GridSearchCV(clf, scoring='roc_auc', cv=3, return_train_score=True, param_grid=parameters, n_jobs=-1).fit(X_train, y_train)

# %%
# wyniki dla najlepszego znalezionego parametru
print(round(k_best_search.best_score_, 4), k_best_search.best_params_)
# Out:
# 0.715 {'select__k': 10}

# %%
show_scores(k_best_search.best_estimator_, X_train, y_train)
show_scores(k_best_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |           940 |             0 |
#
# accuracy:              0.9616
# precision:             0.0
# recall:                0.0
# f1:                    0.0
# roc_auc_discrete:      0.5
# roc_auc_continuous:    0.7189
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         10050 |             0 |
# |           450 |             0 |
#
# accuracy:              0.9571
# precision:             0.0
# recall:                0.0
# f1:                    0.0
# roc_auc_discrete:      0.5
# roc_auc_continuous:    0.7151

# %% [markdown]
# Wyniki dla metryki roc_auc ponownie nic nie dają, sprawdzimy f1

# %%
clf = Pipeline([
    ('select', SelectKBest()),
    ('model', DecisionTreeClassifier(random_state=42))])

parameters = dict(select__k=np.arange(1, 200, 1))
k_best_search = GridSearchCV(clf, scoring='f1', cv=5, return_train_score=True, param_grid=parameters, n_jobs=-1).fit(X_train, y_train)

print(round(k_best_search.best_score_, 4), k_best_search.best_params_)
# Out:
# 0.1531 {'select__k': 106}

# %%
show_scores(k_best_search.best_estimator_, X_train, y_train)
show_scores(k_best_search.best_estimator_, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |            15 |           925 |
#
# accuracy:              0.9994
# precision:             1.0
# recall:                0.984
# f1:                    0.992
# roc_auc_discrete:      0.992
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9624 |           426 |
# |           373 |            77 |
#
# accuracy:              0.9239
# precision:             0.1531
# recall:                0.1711
# f1:                    0.1616
# roc_auc_discrete:      0.5644
# roc_auc_continuous:    0.5651

# %% [markdown]
# Zobaczmy, jak prezentują się wszystkie wyniki

# %%
cvres = k_best_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(round(mean_score, 4), "   ", params)
# Out:
# 0.0     {'select__k': 1}
# 0.0     {'select__k': 2}
# 0.0     {'select__k': 3}
# 0.0     {'select__k': 4}
# 0.0     {'select__k': 5}
# 0.0     {'select__k': 6}
# 0.0     {'select__k': 7}
# 0.0     {'select__k': 8}
# 0.0     {'select__k': 9}
# 0.0     {'select__k': 10}
# 0.0     {'select__k': 11}
# 0.0343     {'select__k': 12}
# 0.0472     {'select__k': 13}
# 0.0419     {'select__k': 14}
# 0.0346     {'select__k': 15}
# 0.0388     {'select__k': 16}
# 0.0393     {'select__k': 17}
# 0.0421     {'select__k': 18}
# 0.04     {'select__k': 19}
# 0.0428     {'select__k': 20}
# 0.0347     {'select__k': 21}
# 0.0361     {'select__k': 22}
# 0.0417     {'select__k': 23}
# 0.0403     {'select__k': 24}
# 0.0399     {'select__k': 25}
# 0.0424     {'select__k': 26}
# 0.0336     {'select__k': 27}
# 0.0451     {'select__k': 28}
# 0.046     {'select__k': 29}
# 0.042     {'select__k': 30}
# 0.0487     {'select__k': 31}
# 0.0451     {'select__k': 32}
# 0.0465     {'select__k': 33}
# 0.0503     {'select__k': 34}
# 0.0463     {'select__k': 35}
# 0.0528     {'select__k': 36}
# 0.0603     {'select__k': 37}
# 0.0595     {'select__k': 38}
# 0.0617     {'select__k': 39}
# 0.063     {'select__k': 40}
# 0.0652     {'select__k': 41}
# 0.0655     {'select__k': 42}
# 0.0643     {'select__k': 43}
# 0.0681     {'select__k': 44}
# 0.063     {'select__k': 45}
# 0.0691     {'select__k': 46}
# 0.0628     {'select__k': 47}
# 0.0689     {'select__k': 48}
# 0.0625     {'select__k': 49}
# 0.064     {'select__k': 50}
# 0.0702     {'select__k': 51}
# 0.0683     {'select__k': 52}
# 0.0659     {'select__k': 53}
# 0.0789     {'select__k': 54}
# 0.0738     {'select__k': 55}
# 0.0722     {'select__k': 56}
# 0.0792     {'select__k': 57}
# 0.0782     {'select__k': 58}
# 0.0979     {'select__k': 59}
# 0.097     {'select__k': 60}
# 0.0995     {'select__k': 61}
# 0.088     {'select__k': 62}
# 0.0905     {'select__k': 63}
# 0.086     {'select__k': 64}
# 0.0884     {'select__k': 65}
# 0.0905     {'select__k': 66}
# 0.0919     {'select__k': 67}
# 0.0819     {'select__k': 68}
# 0.084     {'select__k': 69}
# 0.0834     {'select__k': 70}
# 0.0846     {'select__k': 71}
# 0.0851     {'select__k': 72}
# 0.0839     {'select__k': 73}
# 0.0956     {'select__k': 74}
# 0.0981     {'select__k': 75}
# 0.0871     {'select__k': 76}
# 0.0949     {'select__k': 77}
# 0.1068     {'select__k': 78}
# 0.1116     {'select__k': 79}
# 0.1184     {'select__k': 80}
# 0.1102     {'select__k': 81}
# 0.1369     {'select__k': 82}
# 0.1276     {'select__k': 83}
# 0.124     {'select__k': 84}
# 0.1217     {'select__k': 85}
# 0.1291     {'select__k': 86}
# 0.1316     {'select__k': 87}
# 0.1163     {'select__k': 88}
# 0.1194     {'select__k': 89}
# 0.1284     {'select__k': 90}
# 0.1355     {'select__k': 91}
# 0.141     {'select__k': 92}
# 0.132     {'select__k': 93}
# 0.1284     {'select__k': 94}
# 0.1405     {'select__k': 95}
# 0.1357     {'select__k': 96}
# 0.1447     {'select__k': 97}
# 0.1399     {'select__k': 98}
# 0.1321     {'select__k': 99}
# 0.1405     {'select__k': 100}
# 0.1419     {'select__k': 101}
# 0.1346     {'select__k': 102}
# 0.1377     {'select__k': 103}
# 0.1449     {'select__k': 104}
# 0.1432     {'select__k': 105}
# 0.1531     {'select__k': 106}
# 0.1423     {'select__k': 107}
# 0.1437     {'select__k': 108}
# 0.1467     {'select__k': 109}
# 0.1406     {'select__k': 110}
# 0.1347     {'select__k': 111}
# 0.1466     {'select__k': 112}
# 0.1408     {'select__k': 113}
# 0.1378     {'select__k': 114}
# 0.1427     {'select__k': 115}
# 0.1348     {'select__k': 116}
# 0.1386     {'select__k': 117}
# 0.136     {'select__k': 118}
# 0.1368     {'select__k': 119}
# 0.1381     {'select__k': 120}
# 0.1396     {'select__k': 121}
# 0.1384     {'select__k': 122}
# 0.1402     {'select__k': 123}
# 0.1372     {'select__k': 124}
# 0.1453     {'select__k': 125}
# 0.1383     {'select__k': 126}
# 0.1376     {'select__k': 127}
# 0.1402     {'select__k': 128}
# 0.1396     {'select__k': 129}
# 0.1396     {'select__k': 130}
# 0.1369     {'select__k': 131}
# 0.1394     {'select__k': 132}
# 0.1373     {'select__k': 133}
# 0.1373     {'select__k': 134}
# 0.1387     {'select__k': 135}
# 0.1295     {'select__k': 136}
# 0.1331     {'select__k': 137}
# 0.1264     {'select__k': 138}
# 0.1346     {'select__k': 139}
# 0.1497     {'select__k': 140}
# 0.1411     {'select__k': 141}
# 0.1355     {'select__k': 142}
# 0.1295     {'select__k': 143}
# 0.1353     {'select__k': 144}
# 0.1452     {'select__k': 145}
# 0.1435     {'select__k': 146}
# 0.1462     {'select__k': 147}
# 0.1386     {'select__k': 148}
# 0.1183     {'select__k': 149}
# 0.1333     {'select__k': 150}
# 0.1266     {'select__k': 151}
# 0.1316     {'select__k': 152}
# 0.1353     {'select__k': 153}
# 0.1405     {'select__k': 154}
# 0.1308     {'select__k': 155}
# 0.1322     {'select__k': 156}
# 0.1334     {'select__k': 157}
# 0.1347     {'select__k': 158}
# 0.1384     {'select__k': 159}
# 0.1379     {'select__k': 160}
# 0.1411     {'select__k': 161}
# 0.131     {'select__k': 162}
# 0.1311     {'select__k': 163}
# 0.1376     {'select__k': 164}
# 0.1258     {'select__k': 165}
# 0.1379     {'select__k': 166}
# 0.1251     {'select__k': 167}
# 0.1347     {'select__k': 168}
# 0.1345     {'select__k': 169}
# 0.1316     {'select__k': 170}
# 0.1319     {'select__k': 171}
# 0.1389     {'select__k': 172}
# 0.1302     {'select__k': 173}
# 0.1343     {'select__k': 174}
# 0.1364     {'select__k': 175}
# 0.1344     {'select__k': 176}
# 0.1425     {'select__k': 177}
# 0.1364     {'select__k': 178}
# 0.1348     {'select__k': 179}
# 0.1375     {'select__k': 180}
# 0.1342     {'select__k': 181}
# 0.1378     {'select__k': 182}
# 0.1299     {'select__k': 183}
# 0.1376     {'select__k': 184}
# 0.1315     {'select__k': 185}
# 0.1295     {'select__k': 186}
# 0.1306     {'select__k': 187}
# 0.1379     {'select__k': 188}
# 0.1348     {'select__k': 189}
# 0.1397     {'select__k': 190}
# 0.1308     {'select__k': 191}
# 0.1307     {'select__k': 192}
# 0.14     {'select__k': 193}
# 0.132     {'select__k': 194}
# 0.1321     {'select__k': 195}
# 0.1307     {'select__k': 196}
# 0.1274     {'select__k': 197}
# nan     {'select__k': 198}
# nan     {'select__k': 199}

# %%
clf = Pipeline([
    ('select', SelectKBest(k=106)),
    ('model', DecisionTreeClassifier(random_state=42))])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |            15 |           925 |
#
# accuracy:              0.9994
# precision:             1.0
# recall:                0.984
# f1:                    0.992
# roc_auc_discrete:      0.992
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9624 |           426 |
# |           373 |            77 |
#
# accuracy:              0.9239
# precision:             0.1531
# recall:                0.1711
# f1:                    0.1616
# roc_auc_discrete:      0.5644
# roc_auc_continuous:    0.5651

# %% [markdown]
# ### 4.3.4 Dobór zmiennych na podstawie modelu
#
# Przeprowadzimy dobór cech na podstawie modelu ze znalezionymi najlepszymi parametrami. Zastosujemy metody SelectFromModel - feature importance, Sequential Feature Selection i RFE

# %% [markdown]
# ### SelectFromModel - tree-based feature selection

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

show_scores(clf, X_train, y_train)
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |             3 |           937 |
#
# accuracy:              0.9999
# precision:             1.0
# recall:                0.9968
# f1:                    0.9984
# roc_auc_discrete:      0.9984
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9653 |           397 |
# |           379 |            71 |
#
# accuracy:              0.9261
# precision:             0.1517
# recall:                0.1578
# f1:                    0.1547
# roc_auc_discrete:      0.5591
# roc_auc_continuous:    0.5591

# %%
X_train.shape[1]
# Out:
# 197

# %%
sfl = SelectFromModel(clf, prefit=True)
X_train_t = sfl.transform(X_train)
X_test_t = sfl.transform(X_test)
X_train_t.shape[1]
# Out:
# 22

# %%
clf.fit(X_train_t, y_train)

show_scores(clf, X_train_t, y_train)
show_scores(clf, X_test_t, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |             3 |           937 |
#
# accuracy:              0.9999
# precision:             1.0
# recall:                0.9968
# f1:                    0.9984
# roc_auc_discrete:      0.9984
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          9603 |           447 |
# |           381 |            69 |
#
# accuracy:              0.9211
# precision:             0.1337
# recall:                0.1533
# f1:                    0.1429
# roc_auc_discrete:      0.5544
# roc_auc_continuous:    0.5544

# %% [markdown]
# Obserwujemy niewielkie pogorszenie wyników modelu, ale zredukowaliśmy liczbę cech do zaledwie 22!

# %% [markdown]
# ### Sequential Feature Selection

# %%
sfs = SequentialFeatureSelector(
    DecisionTreeClassifier(random_state=42),
    direction='forward',
    scoring='f1',
    n_features_to_select=50,
    cv=3,
    n_jobs=-1)

pipe = Pipeline([
    ('selector', sfs),
    ('model', DecisionTreeClassifier(random_state=42))]).fit(X_train, y_train)

show_scores(pipe, X_train, y_train)

# %%
show_scores(pipe, X_test_t, y_test)

# %% [markdown]
# Zredukowaliśmy liczbę cech do 50 nie pogarszając wyniku.

# %% [markdown]
# ### Recursive Feature Elimination

# %% [markdown]
# Dla najlepszego modelu drzewa decyzyjnego sprawdźmy które cechy niosą za sobą najwięcej informacji

# %%
k_val = [k for k in range (2,100,2)]
score = []
for k in k_val:

    clf = DecisionTreeClassifier(**rand_search.best_params_)
    rfe = RFE(clf,n_features_to_select = k)
    rfe.fit(X_train, y_train)
    X_train_rfe = rfe.transform(X_train)
    X_test_rfe = rfe.transform(X_test)
    clf.fit(X_train_rfe, y_train)

    y_pred_prob = clf.predict_proba(pd.DataFrame(X_test_rfe))

    score_roc = roc_auc_score(y_test, y_pred_prob[:, 1])
    score.append(score_roc)
    print(score_roc, k)

# %%
plt.stem(score)
plt.xticks(k_val, score)
plt.xlim([-1, 50])
plt.xlabel("K Values")
plt.ylabel("f1 Score")

# %% [markdown]
# ![DCT.png](./Img/dct_rfe.png)
#
# Z powyższego wykresu możemy wyczytać, że najlepiej będzie użyć rfe dla 46 cech.
# W związku z tym spróbujmy użyć PCA na wybranych kolumnach.

# %% [markdown]
# ### Principal component analysis

# %%
rfe = RFE(DecisionTreeClassifier(**rand_search.best_params_, random_state=42),n_features_to_select = 64).fit(X_train, y_train)
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

k_values = [i for i in range (2,72)]
scores = []

for k in k_values:

    clf = DecisionTreeClassifier(**rand_search.best_params_)
    pca = PCA(n_components=k)

    X_red_train = pca.fit_transform(X_train_rfe)
    X_red_test = pca.fit_transform(X_test_rfe)

    clf.fit(X_red_train, y_train)
    y_pred_prob = clf.predict_proba(pd.DataFrame(X_red_test))

    score_roc = roc_auc_score(y_test, y_pred_prob[:, 1])
    scores.append(score_roc)

# %%
plt.stem(scores)
plt.xticks(k_values, scores)
plt.xlim([-1, 72])
plt.xlabel("K Values")
plt.ylabel("roc_auc Score")
plt.title("PCA for decision Tree")

# %% [markdown]
# ![DCT.png](./Img/DCT.png)

# %% [markdown]
# Widzimy więc, że dla tego modelu najlepiej będzie wybrać wartość n_components = 64

# %% [markdown]
# ### 4.4 Podsumowanie
#
# Model drzewa decyzyjnego działa bardzo słabo w przypadku naszego zbioru danych i wykazujemy pewną bezradność wobec tego algorytmu nawet po dość szczegółowym i wielokrotnym przeszukiwaniu siatki parametrów. Niemniej jednak udało nam się przeprowadzić selekcję cech niepogarszającą rezultatów modelu. Metody jakie wybraliśmy i ostateczna liczba zmiennych prezentują się następujaco:
#
# - SelectKBest - 106
# - Tree-based feature selection (feature_importance) - 22
# - Sequential feature selection - 70
# - Recursive feature elimination - 46
# - RFE + PCA - 64
#
# Zwycięzcą w tym modelu okazało się podejście oparte na modelu i parametrze feature_importance. Trzeba jednak pamiętać, że jest ono skuteczne tylko w przypadku nieprzetrenowanego modelu, czego w tym przypadku nie uzyskaliśmy.

# %% [markdown]
# # 5. SVM

# %% [markdown]
# ## 5.1 Preprocessing

# %%
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9995, 0.99, 1)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

float_transformer = Pipeline([
    ('float', ColumnRemover(0.9999, 0.99, 10)),
    ('standard_scaler', StandardScaler())])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

# %%
X_train = train_df.drop('target', axis=1)
y_train = train_df.target
X_test = test_df.drop('target', axis=1)
y_test = test_df.target

# %% [markdown]
# ## 5.2 Trening pierwszego modelu

# %%
clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', SVC(random_state=42, probability=True))])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |           939 |             1 |
#
# accuracy:              0.9617
# precision:             1.0
# recall:                0.0011
# f1:                    0.0021
# roc_auc_discrete:      0.5005
# roc_auc_continuous:    0.5118

# %%
show_scores(clf, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         10050 |             0 |
# |           450 |             0 |
#
# accuracy:              0.9571
# precision:             0.0
# recall:                0.0
# f1:                    0.0
# roc_auc_discrete:      0.5
# roc_auc_continuous:    0.494

# %% [markdown]
# Spróbujmy wyciągnąć lepsze wyniki

# %% [markdown]
# ### 5.2.1 Trening z wybranymi hiperparametrami

# %%
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9995, 0.99, 1)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

float_transformer = Pipeline([
    ('float', ColumnRemover(0.9999, 0.99, 10))])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

X_train = col_transformer.fit_transform(train_df.drop('target', axis=1), train_df.target)
y_train = train_df.target
X_test = col_transformer.transform(test_df.drop('target', axis=1))
y_test = test_df.target

# %%
svm2 = SVC(kernel='linear', class_weight='balanced', gamma='auto',probability=True, random_state=42).fit(X_train,y_train)

# %%
show_scores(svm2, X_train, y_train)
show_scores(svm2, X_test, y_test)

# %% [markdown]
# ![svm.png](./img/svm.png)

# %% [markdown]
# Pozostaje kwestia strojenia hiperparametrów i wyboru cech dla tego modelu. Niestety, z naszego doświadczenia wiemy, że czas trwania przeliczenia tego dla SVM jest liczony w dniach (co najmniej kilku). Z tego powodu ograniczyliśmy się jedynie do empirycznego wyboru powyższych hiperparametrów.

# %% [markdown]
# # 6. Random forest

# %% [markdown]
# ## 6.1 Preprocessing

# %%
int_transformer = Pipeline([
    ('int', ColumnRemover(0.9995, 0.99, 1)),
    ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))])

float_transformer = Pipeline([
    ('float', ColumnRemover(0.9999, 0.99, 10))])

col_transformer = ColumnTransformer([
    ('int_pipe', int_transformer, make_column_selector(dtype_include=np.int64)),
    ('float_pipe', float_transformer, make_column_selector(dtype_include=np.float64))
])

# %% [markdown]
# ## 6.2 Trening modelu

# %%
X_train = train_df.drop('target', axis=1)
y_train = train_df.target
X_test = test_df.drop('target', axis=1)
y_test = test_df.target

# %%
rf = RandomForestClassifier(random_state=42, n_estimators=1000)

clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', rf)])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)

# %%
show_scores(clf, X_test, y_test)

# %% [markdown]
# Model jest bardzo przeuczony, spróbujmy ustawić parametry dla znalezione dla najlepszego pojedynczego drzewa decyzyjnego.

# %%
rf = RandomForestClassifier(random_state=42, n_estimators=1000, **rand_search.best_params_)

clf = Pipeline([
    ('preprocessing', col_transformer),
    ('model', rf)])

clf.fit(X_train, y_train)
show_scores(clf, X_train, y_train)

# %%
show_scores(clf, X_test, y_test)

# %% [markdown]
# # 7. Voting

# %% [markdown]
# Zbierzemy teraz najlepsze otrzymane algorytmy regresji logistycznej, drzewa decyzyjnego i svm łącząc je w klasyfikatorze głosującym. Zastosujemy głosowanie miękkie, które lepiej się sprawdzi w naszym przypadku.

# %%
log_reg = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('int_pipe', Pipeline([
            ('int', ColumnRemover(0.9998, 1, 0)),
            ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))]), make_column_selector(dtype_include=np.int64)),
        ('float_pipe', Pipeline([
            ('float', ColumnRemover(0.9996, 0.97, 0)),
            ('min_max', StandardScaler())]), make_column_selector(dtype_include=np.float64))
    ])),
    ('selector_1', SelectKBest(k=33)),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))])

dct = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('int_pipe', Pipeline([
            ('int', ColumnRemover(0.9998, 0.99, 2)),
            ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))]), make_column_selector(dtype_include=np.int64)),
        ('float_pipe', Pipeline([
            ('float', ColumnRemover(0.9998, 0.96, 15)),
            ('min_max', StandardScaler())]), make_column_selector(dtype_include=np.float64))
    ])),
    ('selector_2', SelectFromModel(DecisionTreeClassifier(random_state=42))),
    ('model', DecisionTreeClassifier(random_state=42))])

svc = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('int_pipe', Pipeline([
            ('int', ColumnRemover(0.9995, 0.99, 1)),
            ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))]), make_column_selector(dtype_include=np.int64)),
        ('float_pipe', Pipeline([
            ('float', ColumnRemover(0.9999, 0.99, 10))]), make_column_selector(dtype_include=np.float64))
    ])),
    ('model', SVC(random_state=42, probability=True))])

# %%
estimators=[('DecisionTree', dct), ('SVM', svc), ('LR', log_reg)]
vc = VotingClassifier(estimators=estimators, voting='soft', weights=[0.2, 0.1, 0.7]).fit(X_train, y_train)

# %%
show_scores(vc, X_train, y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         21333 |          2227 |
# |           180 |           760 |
#
# accuracy:              0.9018
# precision:             0.2544
# recall:                0.8085
# f1:                    0.3871
# roc_auc_discrete:      0.857
# roc_auc_continuous:    0.9434

# %%
show_scores(vc, X_test, y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          8944 |          1106 |
# |           236 |           214 |
#
# accuracy:              0.8722
# precision:             0.1621
# recall:                0.4756
# f1:                    0.2418
# roc_auc_discrete:      0.6828
# roc_auc_continuous:    0.7792

# %% [markdown]
# Otrzymaliśmy niespotykanie wysoki dotąd rezultat f1 oraz całkiem przyzwoite inne metryki.

# %% [markdown]
# # 8. Adaboost

# %% [markdown]
# Spróbujmy zastosować Adaboost na pewnych modelach.

# %%
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### Regresja Logistyczna

# %%
log_reg = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('int_pipe', Pipeline([
            ('int', ColumnRemover(0.9998, 1, 0)),
            ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))]), make_column_selector(dtype_include=np.int64)),
        ('float_pipe', Pipeline([
            ('float', ColumnRemover(0.9996, 0.97, 0)),
            ('min_max', StandardScaler())]), make_column_selector(dtype_include=np.float64))
    ])),
    ('selector_1', SelectKBest(k=33)),
    ('model', LogisticRegression(random_state=42, class_weight='balanced'))])

# %%
scaler = MinMaxScaler()
X_train_logreg = scaler.fit_transform(X_train)
X_test_logreg = scaler.fit_transform(X_test)

# %%
ADB_logreg.fit(X_train_logreg, y_train)
show_scores(ADB_logreg, X_train_logreg,y_train)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         16137 |          7423 |
# |           222 |           718 |
#
# accuracy:              0.688
# precision:             0.0882
# recall:                0.7638
# f1:                    0.1581
# roc_auc_discrete:      0.7244
# roc_auc_continuous:    0.7998

# %%
show_scores(ADB_logreg, X_test_logreg,y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |          7167 |          2883 |
# |           142 |           308 |
#
# accuracy:              0.7119
# precision:             0.0965
# recall:                0.6844
# f1:                    0.1692
# roc_auc_discrete:      0.6988
# roc_auc_continuous:    0.7702

# %% [markdown]
# ### Drzewa decyzyjne

# %%
dct = Pipeline([
    ('preprocessor', ColumnTransformer([
        ('int_pipe', Pipeline([
            ('int', ColumnRemover(0.9998, 0.99, 2)),
            ('one_hot', OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype='int64'))]), make_column_selector(dtype_include=np.int64)),
        ('float_pipe', Pipeline([
            ('float', ColumnRemover(0.9998, 0.96, 15)),
            ('min_max', StandardScaler())]), make_column_selector(dtype_include=np.float64))
    ])),
    ('selector_2', SelectFromModel(DecisionTreeClassifier(random_state=42))),
    ('model', DecisionTreeClassifier(random_state=42))])

# %%
ADB_dct = AdaBoostClassifier(base_estimator=clf, n_estimators=1000,learning_rate=0.5,
                         algorithm='SAMME.R', random_state=42)

# %%
ADB_dct.fit(X_train, y_train)
show_scores(ADB_dct, X_train,y_train)
show_scores(ADB_dct, X_test,y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23560 |             0 |
# |             3 |           937 |
#
# accuracy:              0.9999
# precision:             1.0
# recall:                0.9968
# f1:                    0.9984
# roc_auc_discrete:      0.9984
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         10032 |            18 |
# |           443 |             7 |
#
# accuracy:              0.9561
# precision:             0.28
# recall:                0.0156
# f1:                    0.0295
# roc_auc_discrete:      0.5069
# roc_auc_continuous:    0.6767

# %%
ADB_dct = AdaBoostClassifier(base_estimator=clf, n_estimators=2000,learning_rate=0.5,
                         algorithm='SAMME.R', random_state=42)

# %%
ADB_dct.fit(X_train, y_train)
show_scores(ADB_dct, X_train,y_train)
show_scores(ADB_dct, X_test,y_test)
# Out:
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         23559 |             1 |
# |             2 |           938 |
#
# accuracy:              0.9999
# precision:             0.9989
# recall:                0.9979
# f1:                    0.9984
# roc_auc_discrete:      0.9989
# roc_auc_continuous:    1.0
# |   Predicted 0 |   Predicted 1 |
# |---------------+---------------|
# |         10031 |            19 |
# |           443 |             7 |
#
# accuracy:              0.956
# precision:             0.2692
# recall:                0.0156
# f1:                    0.0294
# roc_auc_discrete:      0.5068
# roc_auc_continuous:    0.6844

# %% [markdown]
# Jak widać, adaboost może pomóc w drzewach decyzyjnych, ponieważ znacznie poprawia roc_auc_continuous. Jednakże dla regresji logistycznej jest on niepotrzebny, wręcz niewskazany

# %% [markdown]
# # 9. Podsumowanie projektu

# %% [markdown]
# W powyższym projekcie rozpoczęliśmy z 300 zmiennymi i jedną zmienną przewidywaną.
#
# Na początku zajeliśmy się preprocessingiem. Postanowiliśmy podzielić go na zmienne całkowitoliczbowe i zmiennoprzecinkowe. Wyrzuciliśmy zmienne noszące takie same dane, zmienne skorelowane, stałe i nie noszące informacji.

# %% [markdown]
# Następnie zajęliśmy się modelami. Postanowiliśmy oceniać wyniki na podstawie polem pod krzywą roc_auc. Wyniki wyglądają następująco:

# %% [markdown]
# |Model   |No_hyper   |Col_rem   |with_hyper   |PCA   |K_best   |SFS   |num_rfe   |num_PCA   |
# |---|---|---|---|---|---|---|---|---|
# |Lin_regrr   |0.806   |0.777   |0.815   |0.738   |   39 / 114 | 50   |72   |3|
# |dec_tree   |0.555   |0.780   |0.799   |0.682   |117 |40 |22 | 64|
#
# |Model   |No_hyper   |with_hyper   |
# |---|---|---|
# |SVC   |0.670   |0.768   |
# |KNN   |0.542 |0.570   |
# |rand_forest   |0.796   | 0.800   |
# |AdaBoost logreg  |0.774   |0.799   |
# |AdaBoost dct  |0.676   |0.684   |
# |Voting   |   |   |

# %% [markdown]
# Jak możemy zauważyć, funkcje które zmniejszały liczbę cech pogarszały wyniki modeli. Postanowiliśmy je jednak pokazać, ponieważ poprawa wydajności którą niesie ze sobą stosowanie tych funkcji znacznie pomaga w obliczeniach.
